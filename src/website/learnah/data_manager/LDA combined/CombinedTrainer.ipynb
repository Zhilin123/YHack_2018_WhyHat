# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
import numpy as np
import pandas as pd
from ast import literal_eval
from gensim import corpora, models, similarities
from nltk.tokenize import sent_tokenize, word_tokenize
from stop_words import get_stop_words
from random import shuffle
import stop_words
from gensim.parsing.porter import PorterStemmer
import time
import re
import json, os, pickle
import matplotlib.pyplot as plt
import pyLDAvis
import pyLDAvis.gensim
# Out:
# 2018-12-01 19:22:26,369 : INFO : 'pattern' package found; tag filters are available for English

# %%
from TextCleaner import TextCleaner

# %%
class SubjectTrainer():
    """
    The class for training topic model
    """
    def __init__(self, folder="./subject_models", cl_folder="../text_cleaner_models_with_subjects/"):
        """
        Initialize
        """
        # init model folder
        self.folder = folder
        try:
            os.mkdir(folder)
        except:
            pass
        
        # load string cleaner
        self.cl = TextCleaner(folder=cl_folder)
        
        # init index model variables
        self.model = None
        self.dictionary = None
        
        # topic index: topic_name . topic_index
        self.topic_index = {}
        
        # indexed topic: topic_index . topic_name
        self.indexed_topic = []
        
        # topic vec: topic_index . topic_model_vec
        self.topic_vec = None
        
        # video index: video_name . video_index
        self.video_index = {}
        
        # indexed video: video_index . video_name
        self.indexed_video = []
        
        # video topic vec: video_index . topic_vec
        self.video_topic_vec = {}
        
        # video vec: video_index . topic_model_vec
        self.video_vec = {}
        
    def train_topic_model(self, cleaned_docs, vec_len=150):
        """
        Train topic model and save the:
        model, tfidf and dictionary model
        """
        print("start training topic model")
        
        # init topic model vector length
        self.vec_len = vec_len
        
        # get dictionary
        self.dictionary = corpora.Dictionary([doc.split() for doc in cleaned_docs])
        
        # remove organization specific words
        self.dictionary.filter_extremes(no_below=5, no_above=0.5)
        self.dictionary.compactify()
        print("dicionary collected")
        
        # prepare topic model
        bows = [self.dictionary.doc2bow(doc.split()) for doc in cleaned_docs]
        self.model = models.LdaModel(bows, self.vec_len, id2word=self.dictionary, chunksize=2000, passes=50, 
                                         iterations=100, alpha="auto", eta="auto", eval_every=80000
                                        )
        print("topic model generated")
        
        # save to file
        self.dictionary.save(self.folder + "/" + "dictionary")
        self.model.save(self.folder + "/" + "model")
        
    def index_topic_and_video(self, topics, videos, existing_video_index=None):
        """
        Index all documents to get self: topic_index, topic_vec, video_topic_vec and video_vec
        
        topics: dictionary of topic name and topic texts
        videos: dictionary of video name and video subtitles
        """ 
        # create video_index and indexed_video if no existing video index and indexed video
        if existing_video_index is None:
            v_counter = 0
            for v in videos:
                self.video_index[v] = v_counter
                self.indexed_video.append(v)
                v_counter += 1
        else: # load existing video index
            self.video_index = existing_video_index["video_index"]
            self.indexed_video = existing_video_index["indexed_video"]
            v_counter = len(self.indexed_video)
        
        # create topic_index and indexed_topic
        t_counter = 0
        for t in topics:
            self.topic_index[t] = t_counter
            self.indexed_topic.append(t)
            t_counter += 1
        
        # create topic_vec
        self.topic_vec = np.zeros((t_counter, self.vec_len))
        for t in topics:
            t_vec = self.index_text(topics[t], norm=None, thresh=30)
            self.topic_vec[self.topic_index[t], :] = t_vec
            
        # create video_vec:
        self.video_vec = np.zeros((v_counter, self.vec_len))
        for v in videos:
            v_vec = self.index_text(videos[v], norm=None, thresh=1)
            self.video_vec[self.video_index[v], :] = v_vec
            
        # create video_topic_vec, preserve the original similarity score
        self.video_topic_vec = self.norm_dot(self.video_vec, self.topic_vec)

        # save self. topic_index, indexed_topic, topic_vec, video_index, indexed_video, video_vec, video_topic_vec
        np.save(self.folder + "/topic_vec", self.topic_vec)
        np.save(self.folder + "/video_vec", self.video_vec)
        np.save(self.folder + "/video_topic_vec", self.video_topic_vec)
        with open(self.folder + "/topic_index.pkl", 'wb') as f:
            pickle.dump(self.topic_index, f)
        with open(self.folder + "/indexed_topic.pkl", 'wb') as f:
            pickle.dump(self.indexed_topic, f)
        with open(self.folder + "/video_index.pkl", 'wb') as f:
            pickle.dump(self.video_index, f)
        with open(self.folder + "/indexed_video.pkl", 'wb') as f:
            pickle.dump(self.indexed_video, f)
    
    def load_topic_model(self):
        """
        load topic models if no training is needed
        """
        self.dictionary = corpora.Dictionary.load(self.folder + "/dictionary")
        self.model = models.LdaModel.load(self.folder + "/model")
        self.vec_len = self.model.num_topics
        
    def load_topic_video_model(self):
        """
        load topic_index, indexed_topic, topic_vec, video_index, indexed_video, video_vec, video_topic_vec
        """
        self.topic_vec = np.load(self.folder + "/topic_vec.npy")
        self.video_vec = np.load(self.folder + "/video_vec.npy")
        self.video_topic_vec = np.load(self.folder + "/video_topic_vec.npy")
        with open(self.folder + "/topic_index.pkl", 'rb') as f:
            self.topic_index = pickle.load(f)
        with open(self.folder + "/indexed_topic.pkl", 'rb') as f:
            self.indexed_topic = pickle.load(f)
        with open(self.folder + "/video_index.pkl", 'rb') as f:
            self.video_index = pickle.load(f)
        with open(self.folder + "/indexed_video.pkl", 'rb') as f:
            self.indexed_video = pickle.load(f)
        
    def index_text(self, text, norm=None, thresh=0.05):
        """
        Index a given string use topic model
        """
        # clean the text
        cleaned_text = self.cl.clean(text)

        # get topic model index
        model_vec = self.model.inference([self.dictionary.doc2bow(cleaned_text.split())])[0][0]
        
        # topics that has prob lower than thresh would be set to zero
        model_vec -= thresh
        model_vec[model_vec<0] = 0
        
        # return zero array if no significant topic possibility
        if model_vec.sum() == 0:
            return model_vec
        
        # do norm if necessary
        if norm is None:
            return model_vec
        else:
            return model_vec / np.linalg.norm(model_vec, ord=norm)
        
    def norm_dot(self, a, b):
        """
        A dot operation that is aim to find all cos similarity of each row of each array
        """
        # get per row norm for each array
        norm_a = np.linalg.norm(a, ord=2, axis=1).reshape(-1, 1)
        norm_b = np.linalg.norm(b, ord=2, axis=1).reshape(-1, 1)
        
        # get similarity by doting normalized array rows
        sim = np.dot(a / norm_a, (b / norm_b).T)
        
        np.nan_to_num(sim, copy=False)
        
        return sim

# %%
class InterestTrainer():
    """
    The class for training topic model
    """
    def __init__(self, folder="./asym_150_both", cl_folder="../text_cleaner_models_without_subjects/"):
        """
        Initialize
        """
        # init model folder
        self.folder = folder
        try:
            os.mkdir(folder)
        except:
            pass
        
        # load string cleaner
        self.cl = TextCleaner(folder=cl_folder)
        
        # init index model variables
        self.model = None
        self.dictionary = None
        
        # topic index: topic_name . topic_index
        self.topic_index = {}
        
        # indexed topic: topic_index . topic_name
        self.indexed_topic = []
        
        # topic vec: topic_index . topic_model_vec
        self.topic_vec = None
        
        # video index: video_name . video_index
        self.video_index = {}
        
        # indexed video: video_index . video_name
        self.indexed_video = []
        
        # video topic vec: video_index . topic_vec
        self.video_topic_vec = {}
        
        # video vec: video_index . topic_model_vec
        self.video_vec = {}
        
    def train_topic_model(self, cleaned_docs, vec_len=300):
        """
        Train topic model and save the:
        model, tfidf and dictionary model
        """
        print("start training topic model")
        
        # init topic model vector length
        self.vec_len = vec_len
        
        # get dictionary
        self.dictionary = corpora.Dictionary([doc.split() for doc in cleaned_docs])
        
        # remove organization specific words
        self.dictionary.filter_extremes(no_below=10, no_above=0.35)
        self.dictionary.compactify()
        print("dicionary collected")
        
        # prepare topic model
        bows = [self.dictionary.doc2bow(doc.split()) for doc in cleaned_docs]
        self.model = models.LdaModel(bows, self.vec_len, id2word=self.dictionary, chunksize=4000, passes=100, 
                                         iterations=100, alpha="auto", eta="auto", eval_every=80000
                                        )
        print("topic model generated")
        
        # save to file
        self.dictionary.save(self.folder + "/" + "dictionary")
        self.model.save(self.folder + "/" + "model")
        
    def index_topic_and_video(self, topics, videos, existing_video_index=None):
        """
        Index all documents to get self: topic_index, topic_vec, video_topic_vec and video_vec
        
        topics: dictionary of topic name and topic texts
        videos: dictionary of video name and video subtitles
        """ 
        # create video_index and indexed_video if no existing video index and indexed video
        if existing_video_index is None:
            v_counter = 0
            for v in videos:
                self.video_index[v] = v_counter
                self.indexed_video.append(v)
                v_counter += 1
        else: # load existing video index
            self.video_index = existing_video_index["video_index"]
            self.indexed_video = existing_video_index["indexed_video"]
            v_counter = len(indexed_video)
        
        # create topic_index and indexed_topic
        t_counter = 0
        for t in topics:
            self.topic_index[t] = t_counter
            self.indexed_topic.append(t)
            t_counter += 1
        
        # create topic_vec
        self.topic_vec = np.zeros((t_counter, self.vec_len))
        for t in topics:
            t_vec = self.index_text(topics[t], norm=None, thresh=5)
            self.topic_vec[self.topic_index[t], :] = t_vec
            
        # create video_vec:
        self.video_vec = np.zeros((v_counter, self.vec_len))
        for v in videos:
            v_vec = self.index_text(videos[v], norm=None, thresh=1)
            self.video_vec[self.video_index[v], :] = v_vec
            
        # create video_topic_vec, preserve the original similarity score
        self.video_topic_vec = self.norm_dot(self.video_vec, self.topic_vec)

        # save self. topic_index, indexed_topic, topic_vec, video_index, indexed_video, video_vec, video_topic_vec
        np.save(self.folder + "/topic_vec", self.topic_vec)
        np.save(self.folder + "/video_vec", self.video_vec)
        np.save(self.folder + "/video_topic_vec", self.video_topic_vec)
        with open(self.folder + "/topic_index.pkl", 'wb') as f:
            pickle.dump(self.topic_index, f)
        with open(self.folder + "/indexed_topic.pkl", 'wb') as f:
            pickle.dump(self.indexed_topic, f)
        with open(self.folder + "/video_index.pkl", 'wb') as f:
            pickle.dump(self.video_index, f)
        with open(self.folder + "/indexed_video.pkl", 'wb') as f:
            pickle.dump(self.indexed_video, f)
    
    def load_topic_model(self):
        """
        load topic models if no training is needed
        """
        self.dictionary = corpora.Dictionary.load(self.folder + "/dictionary")
        self.model = models.LdaModel.load(self.folder + "/model")
        self.vec_len = self.model.num_topics
        
    def load_topic_video_model(self):
        """
        load topic_index, indexed_topic, topic_vec, video_index, indexed_video, video_vec, video_topic_vec
        """
        self.topic_vec = np.load(self.folder + "/topic_vec.npy")
        self.video_vec = np.load(self.folder + "/video_vec.npy")
        self.video_topic_vec = np.load(self.folder + "/video_topic_vec.npy")
        with open(self.folder + "/topic_index.pkl", 'rb') as f:
            self.topic_index = pickle.load(f)
        with open(self.folder + "/indexed_topic.pkl", 'rb') as f:
            self.indexed_topic = pickle.load(f)
        with open(self.folder + "/video_index.pkl", 'rb') as f:
            self.video_index = pickle.load(f)
        with open(self.folder + "/indexed_video.pkl", 'rb') as f:
            self.indexed_video = pickle.load(f)
        
    def index_text(self, text, norm=None, thresh=0.05):
        """
        Index a given string use topic model
        """
        # clean the text
        cleaned_text = self.cl.clean(text)

        # get topic model index
        model_vec = self.model.inference([self.dictionary.doc2bow(cleaned_text.split())])[0][0]
        
        # topics that has prob lower than thresh would be set to zero
        model_vec -= thresh
        model_vec[model_vec<0] = 0
        
        # return zero array if no significant topic possibility
        if model_vec.sum() == 0:
            return model_vec
        
        # do norm if necessary
        if norm is None:
            return model_vec
        else:
            return model_vec / np.linalg.norm(model_vec, ord=norm)
        
    def norm_dot(self, a, b):
        """
        A dot operation that is aim to find all cos similarity of each row of each array
        """
        # get per row norm for each array
        norm_a = np.linalg.norm(a, ord=2, axis=1).reshape(-1, 1)
        norm_b = np.linalg.norm(b, ord=2, axis=1).reshape(-1, 1)
        
        # get similarity by doting normalized array rows
        sim = np.dot(a / norm_a, (b / norm_b).T)
        
        np.nan_to_num(sim, copy=False)
        
        return sim

# %% [markdown]
# # Train the subject model to have the same index as interest model

# %%
from anytree import Node, RenderTree
from anytree.importer import DictImporter
importer = DictImporter()
# load subjects as topics
topics = {}
with open("../text_resource/tree.json", "r") as f:
    tree = importer.import_(json.load(f))
with open("../text_resource/node2text.json", "r") as f:
    node2text = json.load(f)

leaf_nodes = []
def get_leaf_node(node):
    if node.is_leaf:
        leaf_nodes.append(node)
    else:
        for child in node.children:
            get_leaf_node(child)
get_leaf_node(tree)

for node in leaf_nodes:
    text = node2text[node.name]
    topics[node.name] = text
    
# prepare documents of videos
with open("../text_resource/cleaned_subtitles.json", "r") as f:
    o_videos = json.load(f)
# clean up names
videos = {}
for ov in o_videos:
    v = re.sub("(.*/)", "", ov)
    v = re.sub(".en.json", "", v)
    videos[(v[:-12], v[-11:])] = o_videos[ov]

# %%
interest_t = InterestTrainer()
interest_t.load_topic_model()
interest_t.load_topic_video_model()
existing_video_index = {}
existing_video_index["indexed_video"] = interest_t.indexed_video
existing_video_index["video_index"] = interest_t.video_index
# Out:
# 2018-12-01 19:30:15,080 : INFO : loading Phraser object from ../text_cleaner_models_without_subjects//bigram
# 2018-12-01 19:30:15,092 : INFO : loaded ../text_cleaner_models_without_subjects//bigram
# 2018-12-01 19:30:15,094 : INFO : loading Phraser object from ../text_cleaner_models_without_subjects//trigram
# 2018-12-01 19:30:15,103 : INFO : loaded ../text_cleaner_models_without_subjects//trigram
# 2018-12-01 19:30:15,105 : INFO : loading Dictionary object from ./asym_150_both/dictionary
# 2018-12-01 19:30:15,117 : INFO : loaded ./asym_150_both/dictionary
# 2018-12-01 19:30:15,120 : INFO : loading LdaModel object from ./asym_150_both/model
# 2018-12-01 19:30:15,123 : INFO : loading expElogbeta from ./asym_150_both/model.expElogbeta.npy with mmap=None
# 2018-12-01 19:30:15,136 : INFO : setting ignored attribute id2word to None
# 2018-12-01 19:30:15,139 : INFO : setting ignored attribute state to None
# 2018-12-01 19:30:15,142 : INFO : setting ignored attribute dispatcher to None
# 2018-12-01 19:30:15,144 : INFO : loaded ./asym_150_both/model
# 2018-12-01 19:30:15,146 : INFO : loading LdaModel object from ./asym_150_both/model.state
# 2018-12-01 19:30:15,276 : INFO : loaded ./asym_150_both/model.state

# %%
subject_t = SubjectTrainer()
subject_t.load_topic_model()
subject_t.index_topic_and_video(topics, videos, existing_video_index=existing_video_index)
# Out:
# 2018-12-01 19:30:15,790 : INFO : loading Phraser object from ../text_cleaner_models_with_subjects//bigram
# 2018-12-01 19:30:15,799 : INFO : loaded ../text_cleaner_models_with_subjects//bigram
# 2018-12-01 19:30:15,801 : INFO : loading Phraser object from ../text_cleaner_models_with_subjects//trigram
# 2018-12-01 19:30:15,808 : INFO : loaded ../text_cleaner_models_with_subjects//trigram
# 2018-12-01 19:30:15,810 : INFO : loading Dictionary object from ./subject_models/dictionary
# 2018-12-01 19:30:15,814 : INFO : loaded ./subject_models/dictionary
# 2018-12-01 19:30:15,816 : INFO : loading LdaModel object from ./subject_models/model
# 2018-12-01 19:30:15,818 : INFO : loading expElogbeta from ./subject_models/model.expElogbeta.npy with mmap=None
# 2018-12-01 19:30:15,821 : INFO : setting ignored attribute id2word to None
# 2018-12-01 19:30:15,823 : INFO : setting ignored attribute dispatcher to None
# 2018-12-01 19:30:15,825 : INFO : setting ignored attribute state to None
# 2018-12-01 19:30:15,826 : INFO : loaded ./subject_models/model
# 2018-12-01 19:30:15,828 : INFO : loading LdaModel object from ./subject_models/model.state
# 2018-12-01 19:30:15,840 : INFO : loaded ./subject_models/model.state
# /Users/andywu/anaconda3/envs/tensorflow/lib/python3.5/site-packages/ipykernel_launcher.py:184: RuntimeWarning: invalid value encountered in true_divide

# %%
subject_t.indexed_video == interest_t.indexed_video
# Out:
# True

# %%
class InterestVectorizer():
    """
    The class for training topic model
    """
    def __init__(self, folder="./asym_150_both", cl_folder="../text_cleaner_models_without_subjects", 
                 existing_video_index=None
                ):
        """
        Initialize and load all models
        """
        # init model folder
        self.folder = folder

        # load topic models if no training is needed
        self.dictionary = corpora.Dictionary.load(self.folder + "/dictionary")
        self.model = models.LdaModel.load(self.folder + "/model")
        self.vec_len = self.model.num_topics
        
        # load topic_index, indexed_topic, topic_vec, video_index, indexed_video, video_vec, video_topic_vec
        self.topic_vec = np.load(self.folder + "/topic_vec.npy")
        self.video_vec = np.load(self.folder + "/video_vec.npy")
        self.video_topic_vec = np.load(self.folder + "/video_topic_vec.npy")
        self.topic_video_vec = self.video_topic_vec.T
        with open(self.folder + "/topic_index.pkl", 'rb') as f:
            self.topic_index = pickle.load(f)
        with open(self.folder + "/indexed_topic.pkl", 'rb') as f:
            self.indexed_topic = pickle.load(f)
        if existing_video_index is None:
            with open(self.folder + "/video_index.pkl", 'rb') as f:
                self.video_index = pickle.load(f)
            with open(self.folder + "/indexed_video.pkl", 'rb') as f:
                self.indexed_video = pickle.load(f)
        else:
            self.video_index = existing_video_index["video_index"]
            self.indexed_video = existing_video_index["indexed_video"]
        
        # load string cleaner
        self.cl = TextCleaner(folder=cl_folder)
    
    def score_video_based_on_interest_vector(self, interest_vec, thresh=0.05):
        """
        With the input interest vector, return a score for all the videos
        Removing video whose similarity to the topic is less then thresh
        Be advised, do not normalize video topic vec as we are not summing the simlarities of videos
            to different 
        """
        if interest_vec.sum() == 0: # normally distributed interest if no interest is registered
            normed_interest_vector = np.ones_like(normed_interest_vector)
            normed_interest_vector /= normed_interest_vector.sum()
        else:
            normed_interest_vector = interest_vec / interest_vec.sum()
        video_score = np.dot(self.video_topic_vec, normed_interest_vector).reshape(-1)
        
        return video_score
    
    def index_text(self, text, norm=1, thresh=0.05):
        """
        Index a given string use topic model
        """
        # clean the text
        cleaned_text = self.cl.clean(text)

        # get topic model index
        model_vec = self.model.inference([self.dictionary.doc2bow(cleaned_text.split())])[0][0]
        
        # topics that has prob lower than thresh would be set to zero
        model_vec -= thresh
        model_vec[model_vec<0] = 0
        
        # return zero array if no significant topic possibility
        if model_vec.sum() == 0:
            return model_vec
        
        # do norm if necessary
        if norm is None:
            return model_vec
        else:
            return model_vec / np.linalg.norm(model_vec, ord=norm)

# %%
class SubjectVectorizer():
    """
    The class for training topic model
    """
    def __init__(self, folder="./subject_models", cl_folder="../text_cleaner_models_with_subjects/", 
                 existing_video_index=None
                ):
        """
        Initialize and load all models
        """
        # init model folder
        self.folder = folder

        # load topic models if no training is needed
        self.dictionary = corpora.Dictionary.load(self.folder + "/dictionary")
        self.model = models.LdaModel.load(self.folder + "/model")
        self.vec_len = self.model.num_topics
        
        # load topic_index, indexed_topic, topic_vec, video_index, indexed_video, video_vec, video_topic_vec
        self.topic_vec = np.load(self.folder + "/topic_vec.npy")
        self.video_vec = np.load(self.folder + "/video_vec.npy")
        self.video_topic_vec = np.load(self.folder + "/video_topic_vec.npy")
        self.topic_video_vec = self.video_topic_vec.T
        with open(self.folder + "/topic_index.pkl", 'rb') as f:
            self.topic_index = pickle.load(f)
        with open(self.folder + "/indexed_topic.pkl", 'rb') as f:
            self.indexed_topic = pickle.load(f)
        if existing_video_index is None:
            with open(self.folder + "/video_index.pkl", 'rb') as f:
                self.video_index = pickle.load(f)
            with open(self.folder + "/indexed_video.pkl", 'rb') as f:
                self.indexed_video = pickle.load(f)
        else:
            self.video_index = existing_video_index["video_index"]
            self.indexed_video = existing_video_index["indexed_video"]
        
        # load string cleaner
        self.cl = TextCleaner(folder=cl_folder)
    
    def score_video_based_on_topic(self, topics, thresh=0.6):
        """
        With the input topics, return a score for all the videos
        Removing video whose similarity to the topic is less then thresh
        """
        video_score_sum = np.zeros(len(self.indexed_video))
        for t in topics:
            ti = self.topic_index[t]
            video_score = self.topic_video_vec[ti].copy()
            video_score[video_score<thresh] = 0
            video_score_sum += video_score
        video_score_sum[video_score_sum<thresh] = 0
            
        return video_score_sum / len(topics)

# %%
class VideoVectorizer():
    def __init__(self, folder="."):
        """
        Load from folder vectorizer for interest and subject
        """
        # load vectorizer
        self.interest = InterestVectorizer(folder=folder + "/asym_150_both", cl_folder=folder + "/text_cleaner_models_without_subjects")
        self.subject = SubjectVectorizer(folder=folder + "/subject_models", cl_folder=folder + "/text_cleaner_models_with_subjects")
        
        # get the common video index
        self.indexed_video = self.interest.indexed_video
        self.video_index = self.subject.video_index
        
    def update_interest_vector(self, prev_interest_vec, prev_video, update_constant=0.1):
        """
        update interest vector with EMS
        """
        prev_video_interest_vec = self.interest.video_topic_vec[self.video_index[prev_video]]
        
        interest_vec = update_constant * (prev_video_interest_vec - prev_interest_vec) + prev_interest_vec
        
        return interest_vec
        
    def get_ranked_video(self, subjects, interest_vec, subject_weight=0.8, subject_mask_value=0.1, thresh=0):
        # get score for each video based on topics and interests
        interest_score = self.interest.score_video_based_on_interest_vector(interest_vec)
        subject_score = self.subject.score_video_based_on_topic(subjects)
        
        # get the final score, NB video that does not match a subject would not be presented
        final_score = subject_weight * subject_score + (1 - subject_weight) * interest_score
        # get subject mask to mask the final result
        subject_mask = subject_score.copy()
        subject_mask[subject_mask>0] = 1
        subject_mask[subject_mask==0] = subject_mask_value
        # get finally masked result
        final_score *= subject_mask
        
        # give ranked url and title out
        sorted_score = sorted(enumerate(final_score), key=lambda x:x[1], reverse=True)
        
        ranked_video = []
        for index, score in sorted_score:
            if score < thresh:
                break
            ranked_video.append((self.indexed_video[index], score))
        return ranked_video

# %% [markdown]
# # Testing py package

# %%
from VideoVectorizer import *

# %%
vv = VideoVectorizer()
# Out:
# 2018-12-01 20:21:44,609 : INFO : loading Dictionary object from ./asym_150_both/dictionary
# 2018-12-01 20:21:44,621 : INFO : loaded ./asym_150_both/dictionary
# 2018-12-01 20:21:44,624 : INFO : loading LdaModel object from ./asym_150_both/model
# 2018-12-01 20:21:44,627 : INFO : loading expElogbeta from ./asym_150_both/model.expElogbeta.npy with mmap=None
# 2018-12-01 20:21:44,641 : INFO : setting ignored attribute id2word to None
# 2018-12-01 20:21:44,643 : INFO : setting ignored attribute state to None
# 2018-12-01 20:21:44,645 : INFO : setting ignored attribute dispatcher to None
# 2018-12-01 20:21:44,647 : INFO : loaded ./asym_150_both/model
# 2018-12-01 20:21:44,649 : INFO : loading LdaModel object from ./asym_150_both/model.state
# 2018-12-01 20:21:44,765 : INFO : loaded ./asym_150_both/model.state
# 2018-12-01 20:21:44,798 : INFO : loading Phraser object from ./text_cleaner_models_without_subjects/bigram
# 2018-12-01 20:21:44,806 : INFO : loaded ./text_cleaner_models_without_subjects/bigram
# 2018-12-01 20:21:44,809 : INFO : loading Phraser object from ./text_cleaner_models_without_subjects/trigram
# 2018-12-01 20:21:44,817 : INFO : loaded ./text_cleaner_models_without_subjects/trigram
# 2018-12-01 20:21:44,819 : INFO : loading Dictionary object from ./subject_models/dictionary
# 2018-12-01 20:21:44,823 : INFO : loaded ./subject_models/dictionary
# 2018-12-01 20:21:44,825 : INFO : loading LdaModel object from ./subject_models/model
# 2018-12-01 20:21:44,827 : INFO : loading expElogbeta from ./subject_models/model.expElogbeta.npy with mmap=None
# 2018-12-01 20:21:44,831 : INFO : setting ignored attribute id2word to None
# 2018-12-01 20:21:44,833 : INFO : setting ignored attribute dispatcher to None
# 2018-12-01 20:21:44,834 : INFO : setting ignored attribute state to None
# 2018-12-01 20:21:44,836 : INFO : loaded ./subject_models/model
# 2018-12-01 20:21:44,838 : INFO : loading LdaModel object from ./subject_models/model.state
# 2018-12-01 20:21:44,850 : INFO : loaded ./subject_models/model.state
# 2018-12-01 20:21:44,868 : INFO : loading Phraser object from ./text_cleaner_models_with_subjects/bigram
# 2018-12-01 20:21:44,876 : INFO : loaded ./text_cleaner_models_with_subjects/bigram
# 2018-12-01 20:21:44,878 : INFO : loading Phraser object from ./text_cleaner_models_with_subjects/trigram
# 2018-12-01 20:21:44,884 : INFO : loaded ./text_cleaner_models_with_subjects/trigram

# %% [markdown]
# # get video ranks

# %%
topics = vv.subject.indexed_topic[:2]
print("topics are: ", topics)

index = 0
interest_vec = np.zeros_like(vv.interest.video_topic_vec[0])
interest_vec[index] = 1
print("interest is: ", vv.interest.indexed_topic[index])

rank = vv.get_ranked_video(topics, interest_vec, subject_weight=0.5, thresh=0.01)
rank
# Out:
# topics are:  ['Hormonal communication', 'Fluids']
# interest is:  Politics
# [(('What Your Drink Says About Your Politics', 'rdoUojbCfjk'),
#   0.599729720776739),
#  (('Climate Conference - Polar Bears Will Doom Us All', 'dOTGvds7ONs'),
#   0.5274252757909064),
#  (('White House Down - The Psychology of a Secret Service Agent',
#    'ihwzGZlof8M'),
#   0.39212813863424967),
#  (('How Much Neuroscience Is Actually Allowed in the Courtroom',
#    'cT4W-DE9mZ4'),
#   0.32384713146379984),
#  (('How Do Breathalyzers Work', 'rvVzlg26bCM'), 0.2728826333180535),
#  (('Does Alcohol Kill Brain Cells', 'TpgpSIGIczc'), 0.27099006869008263),
#  (('WTF Are Shade Balls', 'xjs4-eCaHUs'), 0.2698188981626893),
#  (('Should We Lower The Drinking Age', 'YBzVN6-9Qi0'), 0.2616336922251012),
#  (('ten-second physics #1', 'YVlCtJ52Juc'), 0.24918188292671284),
#  (('The Chemistry of Champagne', 'rrVgGjuFDus'), 0.24849156010872753),
#  (('How Much Tea Would it Take to Turn the Boston Harbor into Tea',
#    'zME0L1HXqfM'),
#   0.24796153849209968),
#  (('The Endocrine System - Section 35.3', '0X2vkyRklHE'), 0.24191098629575078),
#  (('Does Hot Water Freeze Faster Than Cold Water', 'UjIdzcxSe3g'),
#   0.23789376831525855),
#  (('Weight Loss Pills - Fact Or Fiction', 'gbt0WJTGVSo'), 0.2336029232138705),
#  (("Brinicles - Icicles o' Death", 'L1SO0jL4H40'), 0.23316331825125614),
#  (('Does Pressure Melt Ice', 'gM3zP72-rJE'), 0.23299390358485375),
#  (('Granny Kombat - Granny vs Snake w_ Fatality', '6cXz5vVW8GE'),
#   0.23274855992294402),
#  (('Why Is Ice Slippery', 'Stx6kLd9dYI'), 0.23234854300440677),
#  (('Spinning Disk Trick', 'h0SZZTBQmEs'), 0.23180543525887606),
#  (('What Happens When You Faint', 'GvvH9gd1Njk'), 0.22883534732105917),
#  (('Why does ice float', 'nvcucRLrzuA'), 0.22825355026680488),
#  (('Hydrodynamic Levitation!', 'mNHp8iyyIjo'), 0.22658067072270813),
#  (('The Cold Truth About Fat', 'p-yVmpQoDTk'), 0.22654163972504404),
#  (('Why Are Some People Always Cold', 'DmLqwOKmTdw'), 0.2258664903185491),
#  (('7 Wine Facts & Myths', 'qA9AQGPcOcQ'), 0.2255369563124676),
#  (("Weird Places - Devil's Kettle Falls", 'Ul1b_3eH9sA'), 0.22510420985335475),
#  (('DNews Taste Test - How Spicy Works', 'SdNArpNcS1E'), 0.22507451611616344),
#  (('How to Escape Quicksand', 'n7aHW-Zfzq4'), 0.22444507907510142),
#  (('Ice Cutting Experiment', '1iIv1SuS164'), 0.2242352977750755),
#  (('Absolute Zero - Absolute Awesome', 'TNUDBdv3jWI'), 0.22423319406481515),
#  (("Why Don't Fire Hydrants Freeze and Explode", '_0bRBBYkA1k'),
#   0.22276052139523211),
#  (('The Surprising Benefit Of Reheating Pasta!', 'kos5i74n_1E'),
#   0.22220603577107903),
#  (('Ice Spikes Explained', '5RLQ9WMP2Es'), 0.2221948456790439),
#  (('Why Is Ice Slippery', 'WZV8gM2_MFQ'), 0.22143737668287117),
#  (('How Do You Get Diabetes', 'GmcsG6kLHKo'), 0.22104817569474752),
#  (('Do 3D Printed Guns Require New Laws', '6GITwLGyKyE'), 0.2193982036453876),
#  (('Buoyancy Quiz', 'C_covjcIcZ4'), 0.21937823099053835),
#  (('Does Alcohol Really Keep You Warm', 'qBlERzJGdrs'), 0.21925346392977446),
#  (("World's Roundest Object!", 'ZMByI4s-D-Y'), 0.2186574698899812),
#  (('Amazing Honey Coiling High Speed Video! - Smarter Every Day 53',
#    'zz5lGkDdk78'),
#   0.21865325460675195),
#  (('A Cathedral of Ice', 'AWnB_8IPZ_s'), 0.21859879300130075),
#  (('How Do Glaciers Move', 'RnlPrdMoQ1Y'), 0.21853413474419356),
#  (('What Causes Morning Sickness', '09bCTERVrms'), 0.21815054084038266),
#  (('Does Shivering Help You Lose Weight', 'CqNU6LJNsJ8'), 0.2178313271453131),
#  (('Super Bowl 2014 - Too Soon For Weather Predictions', '2DygssIxEnA'),
#   0.21771935665380465),
#  (("The Science of Caffeine - The World's Most Popular Drug", 'YuJOhpNS0IY'),
#   0.2170686958021718),
#  (('This Itch Is Contagious', 'eHmhsaJDLmk'), 0.21660226567965354),
#  (('Gum + Chocolate = ', 'baC4iuD4gGU'), 0.21595479170130918),
#  (("Why Does Spicy Taste 'Hot' and Minty Taste 'Cool'", 'gwUN8XK3ZO8'),
#   0.21594083156526173),
#  (('Why Is the Perfect Shower Temperature So Hard To Find', 'cAg_3oVL33w'),
#   0.2157634542936191),
#  (('SciShow - Winter Compilation', 'ZyTGFziTw7k'), 0.21561968812270807),
#  (('How Science Affects Your Ice Cream', '-rlapUkWCSM'), 0.21545717236796683),
#  (('How Does Salt Melt Ice', 'JkhWV2uaHaA'), 0.21504540367350847),
#  (('How To Prank Your Friends With Science', '0hhbMi5xFtc'),
#   0.21503344236283245),
#  (('Why Does Beer Make You Pee', 'nN5j0j0Cibc'), 0.21468578558870602),
#  (('Slow Motion Ice Bucket Challenge (Dog, Cat, Chicken, Kid)  - Smarter Every Day',
#    'PYNsp4N8eYg'),
#   0.2146276731407434),
#  (('Why Do Things Feel Hot Or Cold', 'zCJGBA_5PYE'), 0.21455871853622413),
#  (('Strange water phenomenon - Smarter Every Day', 'p7EiT9tKiig'),
#   0.21446533422628247),
#  (('Why Does Skipping Coffee Give Me Headaches', 'zGWZqpHcajY'),
#   0.21423819174756156),
#  (('Beaker Ball Balance Problem', 'QD3hbVG1yxM'), 0.21358211136648877),
#  (('How to Save Smelly Wine - Chemistry Life Hacks', 'rdi66fBn3PU'),
#   0.213521535849502),
#  (('Riding In a Hot Air Balloon Shaped Like a Pig… For SCIENCE',
#    'AqhnZz17amw'),
#   0.2128935644743901),
#  (('What’s The Hottest Hot and Coldest Cold', '1xxsgnEvEfE'),
#   0.2127895254085196),
#  (('Is Glass a Liquid', 'c6wuh0NRG1s'), 0.21233193542878856),
#  (('Round Triangles!', '6MhD2xZVypo'), 0.2123253952962999),
#  (('Underwater Explosions (Science with Alan Sailer!) - Smarter Every Day 63',
#    'Aan-kc-9E3A'),
#   0.2114446192232538),
#  (('Water and Diffusion - The Chemistry of Life', 'oXpOoHc6FEk'),
#   0.21142092816819932),
#  (('Why Do We Feel Emotions In Our Stomachs', 'Az9l33R0mLs'),
#   0.21122415751566262),
#  (('Can We Build Cities Under Water', 'vdGZdmuDu4I'), 0.21115998255613544),
#  (('Caffeine!', 'Xl1XBJLfIDU'), 0.21035889917540898),
#  (('Why You Should Sleep In A Cold Bedroom!', 'kDXSSF_HLu8'),
#   0.20924806093607182),
#  (("What's the Best Way to Pour Beer", 'hTVdVzJtpZI'), 0.20895314599089435),
#  (('Why Your Diet Isn’t Working', 'eZagF3hsBLk'), 0.20875001464195664),
#  (('Performance Enhancing Drugs', 'qfxoqje1X7o'), 0.20847317157614306),
#  (('Does Turkey Really Make You Sleepy - Instant Egghead', 'aa1_CeUAQIc'),
#   0.20804788009253627),
#  (('If Global Warming Is Real, Why Is Antarctic Ice Growing', 'Bm3_sX_obmQ'),
#   0.2079032881401873),
#  (('Plate Tectonics Explained', 'kwfNGatxUJI'), 0.20769662612059103),
#  (('Dude, Transformers are Real!', 'fgN7bYqn3tM'), 0.20735524658668275),
#  (('Keeping Secrets Is Bad For Your Health', 'Yta20wLzA-w'),
#   0.2072507243015573),
#  (('Can You Really Suppress Hunger With A Pill', 'hNbJ9LKEHe8'),
#   0.2058528002495378),
#  (('Supercooled Water - Explained!', 'ph8xusY3GTM'), 0.2058513555589479),
#  (('Does Your Dog Really Need A Sweater', '28tH85aMRDk'), 0.20572469550159964),
#  (('The Thing Scientists Got Wrong About Global Warming', 'RLroXiY4XLY'),
#   0.205417102303158),
#  (('Why Raindrops Are Mathematically Impossible', '8lBvC7aFB40'),
#   0.20536858225242116),
#  (("There's No Such Thing As Cold", 'Akd7MMRKDwc'), 0.20515255749832223),
#  (('Non-Newtonian Fluids & A Bulletproof Hoodie', 'UAqMDeq5hoA'),
#   0.20477014064119028),
#  (('Why Are Belly Flops So Painful', '_Up8ZXaQmXc'), 0.2047325428799075),
#  (('SciShow - You Make Curiosity Contagious', '2VeNDBnuDHs'),
#   0.20439785572973054),
#  (('How Our Ocean Obsession Led To A One-Man Submarine', 'FMdN5YtKhVY'),
#   0.20428766786793612),
#  (('The Leidenfrost Effect - How to Make a Liquid Levitate', '0EOvh0DH_2E'),
#   0.20427612616360877),
#  (('See a Glacier Like Never Before', 'bwNffZfTqIc'), 0.20370895373595713),
#  (('Should You Drink a Bottle of Wine a Day', 'xzUYAQZnQyw'),
#   0.20363461436203448),
#  (('How To Blow Up A Pie!', 'bRItwKfHh_k'), 0.20331369232203347),
#  (('Solution to The Impossible Bet', 'C5-I0bAuEUE'), 0.2032297198245758),
#  (('How to Supercool Water - A SciShow Experiment', 'NMSxuORKynI'),
#   0.20142849520687572),
#  (("World's Longest Vertical Straw", 'HUmZrtiXDik'), 0.20140256093832803),
#  (('How to Create a Hydrothermal Vent - A Step-by-Step Guide', 'o4tseGCl7VI'),
#   0.20130882330116417),
#  (('How Salt Might Be The Key To Finding Life on Mars', 'ZJpdAm8C4kw'),
#   0.19998201598581433),
#  (('Drugs - The Good, The Bad, and Everything In-Between', 'CG0dvN8tb5g'),
#   0.1998940389090164),
#  (('There’s A Blood Test That Can Diagnose Depression!', 'Y5Ehpym8VTw'),
#   0.19964848291476364),
#  (('Chicken Powered Steadicam - Smarter Every Day', 'UytSNlHw8J8'),
#   0.19939580048508965),
#  (('Which came first - Science or Scientists explained in ten seconds',
#    '1TZAmpJ0Jts'),
#   0.19913167795429063),
#  (('What Really Causes a Beer Belly', 'aUx9ha8ntS8'), 0.19893668476128665),
#  (('Footnote † - Unstable Equilibrium', 'plUboQZgkng'), 0.19836971632514241),
#  (('Small Bottle, HUGE Fireball (How Flame Jetting Works)', '5sfUl6GIdYo'),
#   0.19805903718237536),
#  (('The Universe in a Glass of Wine (Richard Feynman Remixed)', 'b3_n7TDL7lc'),
#   0.1976063034101722),
#  (('Why Mixing Alcohol And Caffeine Is So Bad', '4UKjlz7C4zQ'),
#   0.19749773855921549),
#  (('Is America Actually Metric', 'SmSJXC6_qQ8'), 0.19732930663627715),
#  (('Why is it Hot Underground', 'mOSpRzW2i_4'), 0.19732551172909749),
#  (('Does Expensive Wine Really Taste Better', 'intkn2zNTEE'),
#   0.1971126110354563),
#  (('Imploding Drum', 'p3b9pK-O6cE'), 0.1967125397412069),
#  (('Screening Room - Chasing Ice', 'kbuNhMGB4SM'), 0.1966204093290246),
#  (('DIY Macro Lens on the Cheap! - Smarter Every Day 3', 'D9Z9zBmL-VM'),
#   0.196537129167841),
#  (('Can You Change Your Metabolism', 'HXCIv78ACi0'), 0.196447240717609),
#  (('How Air Conditioning Works', 'PT38gaGciP4'), 0.19639370663149283),
#  (('There Are Oceans In Our Solar System That Could Contain Life',
#    'sCv9sucsKkc'),
#   0.19636637375893087),
#  (('100 The Structures On The Distal Humerus', 'bbsuMwlICNI'),
#   0.19626806056447202),
#  (('Why Does Sugar Make My Teeth Hurt', '_gfl-lQtrgo'), 0.19596940559920642),
#  (('Are Energy Drinks Really That Dangerous', 's-7vEPOo-uY'),
#   0.19570404989440535),
#  (('A World Without Helium', 'm_4aZjv9m_w'), 0.19529805056196087),
#  (('Eyeballs vs. Bullets in SlowMo - Smarter Every Day 26', 'NY43w15joPE'),
#   0.19513278713957855),
#  (('Do Fat Cells Ever Really Go Away', 'BzUAllFKTS4'), 0.19492339691685093),
#  (('Why Do Some People Become Alcoholics', 'zLFXZKzYUlE'), 0.194688491509398),
#  (('Can You Keep Donating and Regrowing Your Liver', 'rOv7Sr3X-eo'),
#   0.19450837610760374),
#  (('4 Things No One’s Telling You About the Coming Water World',
#    '4OuR2v0UwHQ'),
#   0.19447868979543287),
#  (('What Really Causes A Food Coma', 'zdjZ6F9Y2ww'), 0.19390497190462588),
#  (('Do You Have a Maximum Heart Rate', '0on5LV3k26o'), 0.1938324107872369),
#  (('Will This Solve Organ Transplant Rejection Forever', 'Z5dP9jiOaN4'),
#   0.19367448275486898),
#  (('The Large Hadron Collider Is Cool', 'DvuxLFgsAQw'), 0.19364070096145214),
#  (('What You Don’t Know About Getting Shots', 'Wm4upMNzSNs'),
#   0.19356062563275728),
#  (('This Bra Offers Emergency Support', 'ATiinXo1qAI'), 0.19340900276004352),
#  (('Why Is Wool Warmer Than Cotton', 'etT1mb1QhuA'), 0.19328222531953382),
#  (("Earth's Not-So-Juicy Center", 'YHqlzCBpu_Q'), 0.19294243084754362),
#  (('How Do Wetsuits Keep You Warm', '6B05sU20-Jw'), 0.19293901989305257),
#  (('Why Does the Cold Make You Pee', '4pUAcK4aRCo'), 0.192912829555205),
#  (('Air Conditioners - Coolest Idea Ever', 'Xnbiz0eNI54'),
#   0.19280802050052304),
#  (('Cellular Respiration Demo using Gummy Bears  -)', 'Kw0fZB72Y-k'),
#   0.19239062473233856),
#  (('Europa', 'pAGKpETmJVw'), 0.19233574170799464),
#  (('How Being Obsessed with Health Can Make You Unhealthy', 'lfvWNFX3Rrk'),
#   0.19124581797524323),
#  (('Why Do We Yawn', 'ew_iZTPoC3c'), 0.19093965324943799),
#  (('Bird Flight - Deep Dive #2 - Smarter Every Day 61', 'DLoI_9Tcl9o'),
#   0.1901902641069035),
#  (('The Hunt For Extraterrestrial Water', '_7Mfweblcng'), 0.18975332520571178),
#  (('The Most Amazing Thing About Trees', 'BickMFHAZR0'), 0.1893982565579458),
#  (('Seeing the Invisible - SLOW MOTION Schlieren Imaging', '4tgOyU34D44'),
#   0.1893195349265543),
#  (('Why You Suck At Gift-Giving', 'H1m12wVoSoc'), 0.18915916889759177),
#  (('Why You Can’t Just Swim Straight Across the Ocean _ The Swim',
#    'Y-DfZueZ-e0'),
#   0.1889973025627438),
#  (('Why Do We Get Thirsty', 'KEyLDRSzbXE'), 0.18890822865494794),
#  (("What is Doping Lance Armstrong's Secrets!", 't6OPh_a11QA'),
#   0.18883702443810677),
#  (('Why Stress Is Good for You - Instant Egghead #40', 'ZlAI_FN3r0k'),
#   0.18882887203517937),
#  (('Do Zombies Float or Sink', 'xrq1U08cpf8'), 0.1887447786219324),
#  (('Climate Change Threatens Coffee and Chocolate', 'pT-rWw7YlKA'),
#   0.18832773429727848),
#  (('4 Common Diet Myths Debunked', '6wNp1fmkOis'), 0.18819443597093083),
#  (('A New State of Water Reveals a Hidden Ocean in Earth’s Mantle',
#    'pgm4z8vJVVk'),
#   0.18805760829338763),
#  (('Why You Should Still Exercise Over the Holidays', '_2IcYgOQ7oU'),
#   0.18781455358148855),
#  (('Why Is The Ocean Salty', 'L9dpXa_Iemo'), 0.18761571497197735),
#  (('Screening Room - Does Somm Take Wine Too Seriously', '9MijcHyLJL0'),
#   0.18760188297433075),
#  (('Spinning Tube Trick', 'wQTVcaA3PQw'), 0.18702126979115175),
#  (('Fun With Potatoes & Physics! A SciShow Experiment', 'j2GK3U_L7bo'),
#   0.1862100695618077),
#  (('Why Is My Poop Green', 'ueOnWXEDBwc'), 0.1860980381907865),
#  (('We Finally Know How The Pyramids Were Made!', 'hRvtVrXcC3Y'),
#   0.18587436429378776),
#  (('The weird chemistry threatening priceless paintings — Speaking of Chemistry',
#    'w2ww5aUJD8s'),
#   0.18540588593530502),
#  (('What Is Night Blindness', 'nnCrnWOiKG4'), 0.18535093588985888),
#  (("Why A Kilogram Isn't Actually 1,000 Grams", 'W0lVZQHHYYQ'),
#   0.18532878319846602),
#  (("First Firing of 'Liberator' 3D Printed Gun", 'IylGx-48TUI'),
#   0.18516987542134083),
#  (('The Napkin Ring Problem', 'J51ncHP_BrY'), 0.18515868323198761),
#  (('SLOW Motion Butterfly Puddling - Smarter Every Day 80', 'v7x4LPhYlbc'),
#   0.18467139136455146),
#  (('Did Dinosaurs Really Have Feathers', 'msk6qabQgPA'), 0.1844961241594936),
#  (('How to Catch Dopers', 'oWOwLwMc0rc'), 0.18399379868859597),
#  (('046 How Adrenaline and Acetylcholine Affect Heart Rate', '2MkYAXTCYcQ'),
#   0.1839470500003065),
#  (('The Impossible Flight Preview', 'SQb1ITj7pkQ'), 0.1838410471422895),
#  (("Why Does My Face Turn Red When I'm Angry", 'eEg3JAOYsw0'),
#   0.18375208029982157),
#  (('Is Air Conditioning Making You Sick', 'JqcyRQsuZjE'), 0.183634471536166),
#  (('Weird Places - The Lava Lake in Antarctica', '0pvtu-ADZSU'),
#   0.18354453493169295),
#  (('Is Caffeine Making Us Crazy', 'xngUYiht-hE'), 0.1835008054888755),
#  (('What Do Artificial Sweeteners Actually Do to Your Body', 'xblFEe9uOqQ'),
#   0.1833008673094574),
#  (('Why Does Coffee Make You Poop', 'cBBu_51QG_k'), 0.18312700298142276),
#  (('Elephant Toothpaste', 'PX7TIqAJRSY'), 0.1829049889424959),
#  (('Could Dinosaurs Have Been Warm-Blooded', 'xdU6qWdF-aI'),
#   0.18273818425912383),
#  (('Why Does Alcohol Burn When You Drink It', 'v5Vwv4eWvL8'),
#   0.18261721747485857),
#  (('Why Does Your Face Turn Red When You Drink', 'oHbKlnOmCtY'),
#   0.1825550209409851),
#  (('Why Are There Clouds', 'QC2x_RRnk8E'), 0.18247284315737333),
#  (("Celsius Didn't Invent Celsius", 'rjht4oAByCI'), 0.18236279128473168),
#  (('Scientists Just Discovered A New State Of Water!', 'flklnj07YqY'),
#   0.1821265308996603),
#  (('Think Tank! - Smarter Every Day 11', 'xGzVjJrcM20'), 0.1815959070661605),
#  (('States of Matter', 'KCL8zqjXbME'), 0.18141388767962582),
#  (('Why Is My Tongue Stuck to This Flagpole', 'h4jBak__Xzk'),
#   0.18103958660797032),
#  (('What the Fahrenheit!', 'LgrXd0NM2y8'), 0.18087995096841455),
#  (('Why is Red Meat ... Red', 'P8umfq5CNLM'), 0.18069115585863488),
#  (('How Can It Be Too Hot To Fly', 'obpdeNWI4BM'), 0.1806900457796695),
#  (('The Lesser Known Benefits Of Probiotics!', '-SqsWBTXHhc'),
#   0.1805571540585962),
#  (('Jumping Water Droplets Could Be the Future of Cooling Computers',
#    '_4QT4mN2BHM'),
#   0.18040505237612042),
#  (('Why Is My Pee Green', 'XKhl2QQUCOs'), 0.18027054425901043),
#  (('What Causes Brain Freeze - Instant Egghead #11', 'gfx19-KACsI'),
#   0.17914996639560088),
#  (('BEST IMAGES OF THE WEEK -  IMG! Episode 23', 'yS-dq_vU9OU'),
#   0.1786971998602994),
#  (('The Reason You Get The Spins When Drunk', '_fRvrKYy_Dk'),
#   0.17868291012325715),
#  (('Why Does Spicy Food Burn When You Poop', '0Bh4wlITDFs'),
#   0.17849560455857832),
#  (('There’s No Such Thing As ‘Earthquake Weather’...Right', 'ahwY9RShm3Q'),
#   0.17846533660383734),
#  (('Why Does Thinking Hard Make You Tired', '2f8wL0r7Fh8'),
#   0.17840114802351126),
#  (('A Scientifically Accurate, Life-Sized Dinosaur Model', 'ueoeO_9Eu_E'),
#   0.1783844462088469),
#  (('053 Cardiac Output', 'Wx1_8iTUanA'), 0.17837936229317244),
#  (('Do Black Holes Ever Die', 'UdUbpdzCdu8'), 0.1781682501880441),
#  (('Peripheral Resistance and Blood Flow', 'MIwP5TX1IrQ'),
#   0.17783120360926696),
#  (('Does Your Bottled Water Come From A Drought Zone', 'uBgb_4DEW-U'),
#   0.17768564378410695),
#  (('What Happens When You Stop Eating', 'RehCW0KM8RM'), 0.17763917872694984),
#  (("We Discovered A Massive Amount Of Water Near The Earth's Core!",
#    'kQHuyu7KQe4'),
#   0.17734158507186132),
#  (('Your Brain In Love', 'sU7lpX6dvF8'), 0.1771524078696808),
#  (('How Coffee is Decaffeinated', 'LCJeRclWv2k'), 0.1766715700513154),
#  (('What Hummingbirds Can Teach Us About Flying', 'ftno9ESWrZM'),
#   0.17645611451777243),
#  (("Should You Walk or Run When It's Cold", 'Re5fhBoF6sY'),
#   0.17607929466389977),
#  (("Einstein's Proof of E=mc²", 'hW7DW9NIO9M'), 0.17586398956223648),
#  (('The Deal with Carbs', 'Q29F4a61J7k'), 0.1755969016589685),
#  (('How Do Helicopters Fly Without Wings', 'pVMT4hqFzQg'), 0.1755047777472706),
#  (('DEEP DIVE #1 - Smarter Every Day 52', 'Q5QTEYwVVaw'), 0.17535552902775514),
#  (('What Caused This Mysterious Huge Crater', 'ux4eFse-MCw'),
#   0.17530924206209253),
#  (('Does the Keto Diet Actually Work', 'UoIW7OARyT0'), 0.17515574885989135),
#  (('Comic-Con 2010 Stand-up Comedy FOR NERDS BY NERDS -- Cross Platform Comedy Will There !!',
#    'qs0QujceVEI'),
#   0.17514128558178668),
#  (('Why Does Putting a Finger Under Your Nose Stop a Sneeze', 'zNSfVz3mGyU'),
#   0.17500051404135986),
#  (('Are You Lightest In The Morning', 'lL2e0rWvjKI'), 0.1748151912686802),
#  (('What Does My Pee Say About Me', 'njwBuVh4dHk'), 0.1743577784561361),
#  (('Meteorite or MeteorWRONG', 'ClW3EB8Ptuw'), 0.17432309421110592),
#  (('Does It Rain Diamonds On Saturn And Jupiter', 'nBGQWTEjA-o'),
#   0.17428733180844677),
#  (('How To Curve A Baseball Or Swing A Cricket Ball', 't-3jnOIJg4k'),
#   0.17413582775495948),
#  (('Does Turkey Really Make You Tired', 'meBrlkvcMhc'), 0.17401904843342597),
#  (('Is it Good to Drink Beer After Working Out', 'W5-MOIf3tss'),
#   0.17395902979595096),
#  (('What Happens if Your Body is Exposed to the Vacuum of Space',
#    'pm6df_SExVw'),
#   0.17376585163411795),
#  (('Why Is The Sound Of Chewing So Awful', 'xN8PG_geu3o'), 0.1737245513233178),
#  (('The Black Hole Tipping Point', 'brmjWYQi2UM'), 0.17356695577208686),
#  (('What Happens If You Go Without Water', 'q3bjUu_ONjc'),
#   0.17350516872675484),
#  (('Auburn Eagle Punches Alabama Fan', 'C2jt-MSmzgw'), 0.1734473695157963),
#  (('Game of Thrones Science - Sword Making and Valyrian Steel', 'cHRcGoje4j4'),
#   0.17331377702547868),
#  (('SciShow Talk Show - Chad Larrabee & Groucho the Hedgehog', 'OUbU0k4_Vr0'),
#   0.17327521558686207),
#  (('Would a Soda Ban Help', 'QZsnCXYFFn0'), 0.1730922199716791),
#  (('COMPLEXITY! -- Vsauce Leanback #6', 'VYqQ-aShpBc'), 0.17274030894203446),
#  (('Getting the Wolf', 'l-QWxuzuB8E'), 0.17272572875654896),
#  (('Is Gluten Sensitivity Actually Real', 'EXON21V0v4o'), 0.17254879842401882),
#  (('How Much Water Do We Really Need to Drink', 'E7NvSjawuiw'),
#   0.17206319166490777),
#  (('Is it OK to Pee in the Ocean', 'eqR2bLsdhs4'), 0.1717855143759258),
#  (('083 The Origin, Insertion, and Action of Pectoralis Minor', 'rVBgTkB4b8w'),
#   0.171741037098488),
#  (("Does Wine Really Need to 'Breathe'", 'lAsBwwU5k-U'), 0.1717407718325939),
#  (('Why Do I Sweat So Much', 'MAUvnCsV6C4'), 0.17153339634318954),
#  (('How To Barbecue Meat The Right Way', 'eH9ZrSIJDxM'), 0.17117572311839208),
#  (('Misconceptions About Temperature', 'vqDbMEdLiCs'), 0.1709648625597084),
#  (('Is Running Really Bad for Your Knees', 'cIbCIXxkB2o'), 0.170652199770749),
#  (('Do Spicy Food Lovers Live Longer', '8C3pEzqr6J0'), 0.17028070564437411),
#  (('Big Idea - Blood Transfusions', 'FmhQkZsyPVQ'), 0.17013735901055577),
#  (('Why is All Sand the Same', 'pxmHHoTPSKI'), 0.1701155169547363),
#  (('Why Do Cats Love Boxes', 'Bbbxd4Tm0F4'), 0.17007002456352618),
#  (('WATER.', 'YMTLkDrcr28'), 0.16997499670058516),
#  (('Pretty People Are Easily Forgotten', 'O8RPOz7KWxg'), 0.16994362334276217),
#  (('How Much Alcohol Can A Pregnant Woman Drink', '7d8jYrlOuz8'),
#   0.16990922361955355),
#  (('Another Physics Misconception', '4B_x1XjBhiI'), 0.16972667021456422),
#  (('Why Do Dogs Pant', 'R8sxpxXjSBs'), 0.1696932666444303),
#  (('What is the Scientific Method (and Can Cats Swim) - Instant Egghead #36',
#    'ex3ciEkbpi8'),
#   0.16960432560803765),
#  (('Why Does Beer Get Skunked', '9i4dHdQzTFg'), 0.16927032451324403),
#  (('Why Earth Has Two Levels _ Hypsometric Curve', 'KOv3FGVmRcA'),
#   0.16924840472399671),
#  (('Why Does Water Go Stale Overnight', 'iF6MS9_sdzg'), 0.16900245931626545),
#  (('088 The Deep Extrinsic Shoulder Muscles', 'DSzEcrYkcrI'),
#   0.16899864131728728),
#  (('There Is Alcohol In Space!', 'aR1qGaal8WQ'), 0.16894817116830804),
#  (('Cheers to the Science of Booze', '0kfhqR1mJ_0'), 0.16886881118381347),
#  (('056 Regulating Peripheral Resistance - Part 2', 'MRcra9oxrXY'),
#   0.1686300726512374),
#  (('Does Water Swirl the Other Way in the Southern Hemisphere', 'mXaad0rsV38'),
#   0.16852345915627273),
#  (('Why Do You Get Hangry', 'JZ6cvJVULp4'), 0.1683577005990073),
#  (('Why Do Coffee Naps Recharge You So Well', '5mfGIfRZtjs'),
#   0.1682213874712515),
#  (('Why Are Mysterious Holes Appearing In Sand Dunes', '83wdjPW3Alk'),
#   0.16810697143931824),
#  (('Take a Trip Through Space!', 'OdVh4LsH0mY'), 0.16798206769424193),
#  (('A Monster Sunspot Is Coming!', 'W_LsKB6mVko'), 0.167952579966181),
#  (('Why Does Getting Water Up Your Nose Hurt So Much', 'ForvnkfjtpY'),
#   0.16777976682231927),
#  (('Nutrition - Section 35.2', 'Hgssih-i9N8'), 0.1677009934634509),
#  (('Banding Baby Dinosaurs', 'sBr9gKlTJAY'), 0.1675740475850638),
#  (('Hydrogen Can Be a Metal! Plus, Other Weird States of Matter (Part 2 of 3)',
#    'W2GHjcFyO3E'),
#   0.1674363421568749),
#  (('The Adrenal Glands - Iron Egghead', 'ax2EQdc-LHs'), 0.1670655984279046),
#  (('What Are Airplane Chemtrails, Really', 'WyHoaThrxSs'),
#   0.16697900932402854),
#  (('What Do Honeybees Do in Winter', 'aPj0W2eT9PM'), 0.16685912516882517),
#  (('Diving Between the Continents (Silfra, Iceland) - Smarter Every Day 161',
#    '5adC3nc0MHI'),
#   0.1668389229229627),
#  (('Couples Who Drink Together, Stay Together', 'TNjgO5XWW74'),
#   0.1667437472117034),
#  (('Water Is Amazing -- World Water Day!', '9m3dQC6IfwY'),
#   0.16674184191271035),
#  (('The 17+ Different Kinds of Ice!', '5FHpk5UeHB8'), 0.166647828169023),
#  (('Comets vs. Asteroids - Instant Egghead # 7', 'uWVd_B0XZdI'),
#   0.16664037493200579),
#  (('How To Breathe Underwater', 'yejDghqigW0'), 0.16656237304765015),
#  (('Why Do People Care About Others', 'f_yB-fp4LJ0'), 0.16654808087578682),
#  (('Why Does The Earth Have Layers', 'WwiiOjyfvAU'), 0.16643854418838216),
#  (('109 The Pathophysiology of Hypertension', 'Ywqcpu7d3Dk'),
#   0.1663254268816793),
#  (('Alcohol, Caffeine, & Opioids - What Happens When You’re Hooked',
#    'GKpAZgrMTC8'),
#   0.16622256756762724),
#  (('Thresher Shark & 3-D Printed Duck Feet', 'H_KcdkkfM9c'),
#   0.16622128451963072),
#  (('Why Do We Get Hiccups', 'uvaADyYk0Mo'), 0.16620888829143218),
#  (('Why Do Golf Balls Have Dimples', '2B_bkDOnwJY'), 0.16616948818271096),
#  (('090 The Deltoideus Muscle - Origin, Insertion, and Action', 'h1Jj5IcUHhU'),
#   0.16606960379973928),
#  (('Shadow Illusion', 'liqF6EamiE4'), 0.165995947262342),
#  (('Why The Full Moon is Better in Winter', 'T3gacnHb9TI'), 0.16589012630644),
#  (('What Happens If We Run Out Of Helium', 'eCorxPmmLa8'), 0.1657915748933854),
#  (('Where Does Love Come From', 'gEFMya7zQKo'), 0.16576736460960856),
#  (('3D Holographic Fetus & Other Incredible 3D Tech', 'q0Z20vjyvBg'),
#   0.1656681175322141),
#  (('SMBC Physics - Why are stones round feat. Zach Weiner', 'w5GHbzR9sZ8'),
#   0.16566759745779552),
#  (('The Crazy Way Scientists Launch Rockets From Balloons', 'Rpj4B23tbhg'),
#   0.16561808506850612),
#  (('What Happens To Your Body When You Fast', 'x0nNgLUb4LM'),
#   0.16555476315834122),
#  (('How to Fry a Thanksgiving Turkey Without Burning Your House Down',
#    't9Dhhxnvt2Y'),
#   0.16548548196278406),
#  (('5 Burning Questions About Water _ Compilation', 'ToOTR3BGICk'),
#   0.1654439023129209),
#  (('Low-Carb vs. Low-Fat - Which Diet Is Better', 'eCpOKzSTyFg'),
#   0.16544012153190066),
#  (('The Science (and Dangers) of Booze in Humans', '2gn-QZ_e06k'),
#   0.16525127442504867),
#  (('How Does Icing an Injury Help', '-P8Qh4MuyVc'), 0.16501108920437174),
#  (('Why Does Toothpaste Make Everything Taste Bad', 'WjeFW6Bda7s'),
#   0.16490390786711331),
#  (('How Long Could You Survive In Outer Space', 'RjkrqMm52JI'),
#   0.16466917064635261),
#  (("Did Aliens Create Saturn's Hexagon", '61mdtQDl9k8'), 0.16449758535799505),
#  (("Mystery of Prince Rupert's Drop at 130,000 fps - Smarter Every Day 86",
#    'xe-f4gokRBs'),
#   0.16436629303410144),
#  (('SciShow - Resolutions Compilation', 'B-OmMkpCrXs'), 0.16425448888735453),
#  (("Weird Things Your Body Does When You're Around Your Crush", 'wRwquGib9IM'),
#   0.16400449484703025),
#  (('The 10 Weirdest Things in the Solar System', 'p_RzJRPPhfw'),
#   0.16389429936952024),
#  (('Antarctic Lava to Pink Snow - The Science of Winter', 't2tKuUxLdMk'),
#   0.1637067834651801),
#  (('How to Pin an Insect', 'MT5VGlSCtg4'), 0.16366460713076),
#  (('Why Sharks', 'v_FRul8yHNs'), 0.16366327468961087),
#  (('How to Explore Otherwordly Oceans', 'p9a0ERM6O80'), 0.16357942120792024),
#  (('The Chemistry of Hollywood Fake Blood', '8OC5rji1stI'),
#   0.16335436295540232),
#  (('Engines of Destruction - The Science of Hurricanes!', 'Xtu2_ziBI_w'),
#   0.1631429485395221),
#  (('Farewell, Montana', 'k27E_lmuIuw'), 0.1630065371282256),
#  (('Make Delicious Ice Cream In 30 Seconds With Dry Ice!', 'qUQljVpXEKU'),
#   0.16300038035457487),
#  (('Could Ice Volcanoes Harbor Alien Life', 'rEl563NBus0'),
#   0.1627615491879981),
#  (('Why Do We Wrinkle When Wet', 'kqhoLNUTS8I'), 0.16275393248349335),
#  (('How To Protect Your Pet From Summer Heat!', 'SIZHEQyCc04'),
#   0.1627331533695466),
#  (("How Pregnancy Shapes The 'Dad Bod'", 'A7I9fND8gHw'), 0.16248560811738294),
#  (('Spinning Tube Trick Answer', 'E9WUaBGH7_I'), 0.16246581425392487),
#  (('Why Does Jupiter Have A Red Spot', 'bFxK9l-ZYdM'), 0.16230470997219),
#  (('6 Everyday Ways Science Protects You from Your Poop', '3UUko1-fCac'),
#   0.16218295325846768),
#  (('Spinning Disk Trick Solution', 'tDr26U49_VA'), 0.16207644038082744),
#  (('Awesome Chemistry Life Hacks (Vol. 3)', 'QUE2O1276P8'),
#   0.1620136219409992),
#  (('Fixed Points', 'csInNn6pfT4'), 0.16192572340164313),
#  (('Why Can the Same Drug Treat Heart Attacks and Anxiety', 'zYqU3aquF9E'),
#   0.1619037495833382),
#  (('Galileo the Scientific Parrot', 'UxbeLdXnaGU'), 0.1617982222636181),
#  (('Life In Space - Living On The ISS', 'pSTp2KOxlOM'), 0.16155706754445978),
#  (('Why Can’t You Buy _Fresh_ Olives', 'oStoeHntfG8'), 0.1612870331581292),
#  (('Can Light and Sound Get You High', 'CjXwJbsW7Og'), 0.16123968779447706),
#  (('Warm-Blooded vs. Cold-Blooded - What’s The Difference', 'LH1p1XOqfsg'),
#   0.1612256856616249),
#  (('Why is Olive Oil Awesome', 'lg1Jy9kx1Kk'), 0.16121264717020714),
#  (('Coffee Can Improve Your Nap!', 'EHgZr9-YpEs'), 0.161137312943372),
#  (("What Causes 'Old People Smell'", 's7zVYJDj2Ok'), 0.16111811028615325),
#  (('What Do Electrolytes Actually Do', 'xhLHtuZ3VOI'), 0.16111173736527826),
#  (('Does Water Ever Expire', 'IqNNteplRvE'), 0.1609901872390693),
#  (('AK-47 Underwater at 27,450 frames per second (Part 2) - Smarter Every Day 97',
#    'cp5gdUHFGIQ'),
#   0.1608762231813101),
#  (('Studying the Solar Eclipse - SciShow Talk Show', 'epVCE7RIeuI'),
#   0.16077278107230994),
#  (('The Limb of the Sun', 'ur0fATmsVoc'), 0.16041224085952852),
#  (('COLD HARD SCIENCE.The Physics of Skating on Ice (With SlowMo) - Smarter Every Day 110',
#    'qd4CVvItJlo'),
#   0.1598671176243588),
#  (('Trilobites So Real They Practically Squirm', '2d9NztifSD4'),
#   0.15979377560823751),
#  (('How An Igloo Keeps You Warm', '1L7EI0vKVuU'), 0.15961281459979007),
#  (('Downhill Rotation Race - Smarter Every Day 13', 't0DFevwfcPE'),
#   0.15951255796223887),
#  (('Matter - You Think You Get It, Then It Turns Into Time Crystals (Part 3 of 3)',
#    'VSm_aXjX0x8'),
#   0.15947213786411996),
#  (('MAKE YOUR CAT A DJ -- and more! LÜT #18', 'Y45aema4iyM'),
#   0.15945559502911627),
#  (('Do Carbs Have Their Own Taste', 'V8z6B_qUZfw'), 0.1593347259645994),
#  (('Why Rocket Launches Always Get Cancelled', 'TzTU-ZfjQlE'),
#   0.1593205749216514),
#  (('A Battery is a Dynamic and Crazy Place, And We Ain’t Li-Ion (Part 2 of 3)',
#    'ZnWW0P-7paE'),
#   0.15911723613825773),
#  (("IDTIMWYTIM - Stochasticity - THAT'S Random", 'LElyagQ0n_g'),
#   0.15897089972013334),
#  (('The Best Way To Swallow Pills', 'bBqrCLS4Mtw'), 0.1588139658498051),
#  (('Urinal Cakes - Why', '6x_MjES5BNA'), 0.1587500604043671),
#  (('4D Printing Self-Building Space Stations!', 'RfW1NYvV0PM'),
#   0.15871461440016094),
#  (('COLD HARD SCIENCE - SLAPSHOT Physics in Slow Motion - Smarter Every Day 112',
#    'IsCdywftyok'),
#   0.1586876661763788),
#  (('Animal Products NOT Essential for Brain Health', 'xYKyO45e0qU'),
#   0.15866664432538521),
#  (('The First Volcano Power Plant!', 'jARDdWuFpK8'), 0.15849141847022158),
#  (('Why Is Your Cat So Disgusted With You', 'drpWDbT37Mk'),
#   0.15838873168076217),
#  (('Poop Can Teach You A Lot, But You Have To Look At It', 'nfQlZ-a9WFs'),
#   0.15834167098923985),
#  (('110 Hypertension Treatment', 'zofXeomRZxQ'), 0.15833313754775885),
#  (('The Science Behind The Swim - Extended Trailer', 'xogqMlKCVkM'),
#   0.15832425110045617),
#  (('Alcohol Is Ruining Your Sperm!', 'uqRO8msLbXQ'), 0.15816936848812094),
#  (('Chicago Adventure, Part Five - The Platypus, The Skin, & The Cold',
#    'ajNN7rXUQvI'),
#   0.15779079887507158),
#  (('What Happens When You Hold Your Pee', 'dg4_deyHLvQ'), 0.15772875785358068),
#  (('Why Do Nuclear Bombs Make Mushroom Clouds', 'wVpRp0Uf-9k'),
#   0.15753758876656437),
#  (('What Causes Morning Sickness', 'Qx37HhEFHFc'), 0.15730995957783783),
#  (('Forget the Apocalypse, Beware of Asteroids!', '4hcAXmd9PGo'),
#   0.1570628906050148),
#  (('Swimming vs. Running - Which Is The Best For You', '5Jcm1RHHTyo'),
#   0.15701477028272245),
#  (('Why Do Tornadoes Hate America', '0yiZveJAEp4'), 0.15683061167295156),
#  (('Why You Look Ugly When You Cry', '22vndEvoSyM'), 0.15681692186459353),
#  (('Geophysics and Earthquake Prediction', 'KCDRZj8mVR0'),
#   0.15679664374597982),
#  (('Why Do Your Eyes Get Red in the Pool', '_gDbazt_u9E'),
#   0.15677539055524248),
#  (('Searching for Life at the Bottom of the Arctic', 'PHJCI7M4knQ'),
#   0.15674153826637047),
#  (('What To Expect at CES 2013!', 'xh46ms1IkQI'), 0.15645970853845),
#  (('Parrot “Giggles” Trigger Play', 'ksHNmEF8a5o'), 0.15633660785832817),
#  (('The How, Why, and How Much of Oil', 'eBBGKx65Ygg'), 0.15629048650485822),
#  (('What Causes PMS', 'W5BvYvyfarw'), 0.15623798158075156),
#  (("What Happens To Your Body When You're Dehydrated", 'AujXYEabz3U'),
#   0.15621045217034965),
#  (("Why Isn't a Kilogram a Kilogram", '5V69ThkahgI'), 0.15617406797781538),
#  (('Why Do Ribbons Curl', 'zsyEMSxN9TM'), 0.15607644363040318),
#  (('Chicken Head Tracking - Smarter Every Day', '_dPlkFPowCc'),
#   0.1559028693214752),
#  (('3 Terrible Old-Timey Ways to (Not) Lose Weight', 'I7ebwR-ij-M'),
#   0.15557328152380542),
#  (('Can Cold Showers Really Improve Your Health', 'HsonXuJs8-s'),
#   0.1554665808504271),
#  (('Vortex Shedding - Smarter Every Day 23', 'ZauGjgZ0rBQ'),
#   0.15545312387201268),
#  (('SPACE STRAW', 'im7DzMr8Ygs'), 0.15540597572684567),
#  (('What Exactly Is The Polar Vortex & Is It Getting Worse', 'B2DtGAlzPYw'),
#   0.15530284018362053),
#  (('Face Tattoos - The Ultimate Declaration of Love', 'cV6fwV9Into'),
#   0.15513954989111367),
#  (('Biddi Bom - A Family Holiday Song', '9Cy3jiiDgoM'), 0.15510128781501334),
#  (('Infuse Cocktails In Under 1 Minute', 'CYAvun9rX8g'), 0.15509251397249654),
#  (('There Are 3,000 Compounds in Your Pee, What Do They Say About Your Health',
#    'HXyq3T5NDyM'),
#   0.15507700981354233),
#  (('Chimera Cats and Your Mom', 'eSMQcy5ReQQ'), 0.1550409778085117),
#  (('Beer Drunk vs. Tequila Drunk - What’s The Difference', 'TIpj9W5IAoI'),
#   0.1550101086215759),
#  (('Why Did You Skip a Period', 'DT37UwFPF8c'), 0.15493661971283224),
#  (("3 Neat Facts About Narwhals (Including - They're Real!)", '15wVJjozM6Q'),
#   0.15489013984371802),
#  (('Yellowstone Steaming Acid Pools of Death', 'OqP50563IDM'),
#   0.15474033758136554),
#  (('Why Does Bonking Beer Bottles Create Foam - Instant Egghead #66',
#    'p11X5ueA6Sk'),
#   0.15462600621546435),
#  (('022 Re - Akbar - Inactivation of V-gated Sodium Channels', 'zH7s4tywHX0'),
#   0.1546222943937803),
#  (("The Only Detox You'll Ever Need", 'zv0chkuT7cQ'), 0.15454180286124364),
#  (('SPACE CATS !!! - Smarter Every Day 85', 'VJcno_XL4RU'),
#   0.1545182661351371),
#  (('Long Distance KISSING and more! LÜT #22', 'L4-F_UakaA8'),
#   0.15450912766415648),
#  (('Breaking the Seal - Fact or Fiction', 'Xt-MPX_oaMs'), 0.15435809999358524),
#  (('Do Ketogenic Diets Really Work', 'nU07pvKK7nw'), 0.15429137038819404),
#  (('Why Does My Poop Float', 'AYSh5gk4xr4'), 0.15428098037059276),
#  (('How Does Powdered Alcohol Work', 'eP8vPZXWadA'), 0.154227644672238),
#  (('Lead - The Original Artificial Sweetener', 'CM1u29BeqC0'),
#   0.15417892242104214),
#  (('How Do Laxatives Work', 'EEBjuiqEp4w'), 0.15404065134122832),
#  (('The Truth About Toilet Swirl - Southern Hemisphere', 'ihv4f7VMeJw'),
#   0.154014028485272),
#  (('What is Cool', 'Af3ZG47oT7I'), 0.15393677567588443),
#  (('Build Your Own Robot Bartender', 'degF0Rp3V3I'), 0.15388609621125085),
#  (('Why Does Beer Foam', 'r2zqG3JnytU'), 0.15388139008350976),
#  (('Spinning Sphere of Molten Sodium', 'rAYW9n8i-C4'), 0.15384980185854788),
#  (('Where Does Fat Go When You Lose Weight', 'WxLc0Z-AD-A'),
#   0.15380549438729163),
#  (('A Beetle’s Beloved Beer Bottle [60 Second Specimens]', 'UMy5-X_wRBQ'),
#   0.15379833197750356),
#  (('What Ever Happened To The Hole In The Ozone Layer', '0ZfBgjUnXIs'),
#   0.15373761633744135),
#  (('Can You Make Beer with Helium-Speaking of Chemistry', 'kV9k9Gpjsgg'),
#   0.15362120735567883),
#  (('Our Brand New DNews Spinoff Is Here!', 'h2qnXO_QiJc'),
#   0.15352651248707913),
#  (('Water Found On Mars... FOR REAL!', '6OMlekqnL8I'), 0.1535084368848627),
#  (('UPSIDE-DOWN Rivers On Mars! (Response to MinutePhysics)', 'yy5UpVoQDJw'),
#   0.15329074007832166),
#  (('Why Do We Breathe', '6MXNstWMaG0'), 0.1532076820140189),
#  (('017 Two Types of Receptors', '8jPH2pKzIDY'), 0.15313981284647302),
#  (('What We Know About Female Ejaculation', 'NHke-ndMnJ0'),
#   0.15308182965337114),
#  (('You Could Live on One of These Moons With an Oxygen Mask and Heavy Jacket',
#    '9t0Cziw6AbI'),
#   0.15290968118660525),
#  (('Introverts and Extroverts Have Different Brains', 'LxZ1fPr9FJg'),
#   0.15274629731277423),
#  (('8 Beautiful, Weird, and Scary Things Ice Can Do', 'b9a36vsQh80'),
#   0.15248838718794683),
#  (('Chemistry Life Hacks for Winter Survival (CLH Vol. 5)', 'cJQ66JvuRaY'),
#   0.15244327469994887),
#  (('How Ghost Particles Are Slowing Down Stars', 'yB8CBEFDNC8'),
#   0.15232005261449527),
#  (('TALKING BACKWARDS (Backwards Banter Brain Testing) - Smarter Every Day 168',
#    'L5cAnxNVWkw'),
#   0.15205658884514073),
#  (('How To Tell If Someone Is Lying To You', 'z4f48M999Rk'),
#   0.1518387058669668),
#  (('Why Do Organ Transplants Fail So Often', 'LQ0K02m6_KM'),
#   0.15178553584261836),
#  (('079 The Ligaments of the Glenohumeral Joint', 'f7g-672pDok'),
#   0.15173830411535644),
#  (('Stop Peeing In The Pool!', '_QYCgpLhaMY'), 0.1516759071291146),
#  (('BEST IMAGES OF THE WEEK - IMG! episode 3', 'CK4oWbidhyQ'),
#   0.15156244379623787),
#  (('A New Pill to Cure Hangovers Is Coming, Here’s How It Works',
#    'Z2h5uA-Xfvk'),
#   0.15153372635598847),
#  (('Superconductor Makes Magnet Levitate - by Scientific American',
#    'DHF72gWXDd8'),
#   0.15146589898288107),
#  (('A Bear Skull', '_rGDpgyBYCw'), 0.15143912291170938),
#  (('7 Organs You Could Totally Live Without', 'EHQ4n980evI'),
#   0.1513542405522313),
#  (('The Truth About Toilet Swirl - Northern Hemisphere', 'aDorTBEhEtk'),
#   0.15129020189555537),
#  (('The Year in Planetary Science', '6yFDWpSqXW0'), 0.15122082898195183),
#  (('How Atom Bombs Can Uncover Forged Art', 'egBZUPVGqj4'),
#   0.15112145605497015),
#  (('How Do We Tell Temperature', 'ibmubP26R9M'), 0.1511023781299886),
#  (('103 The Boundaries of The Cubital Fossa', 'U02ek1to44U'),
#   0.15103116289128235),
#  (("Adam Sessler's Top Gaming Announcements from CES 2013!", 'C3AWAnD_t7Y'),
#   0.15061691345287245),
#  (('Frying Your Way to Better Chicken', 'Vjj2OJBOQ_0'), 0.1505019155619267),
#  (('Mario vs. Link - Who Would Win NERD WARS', 'eyjLSzq9SBo'),
#   0.1504609182073781),
#  (('Why Do You Feel Butterflies in Your Stomach', 'r7yp69Ua37E'),
#   0.1503066501541301),
#  (('The Science of Distance Running', 'AbigOBlkVMU'), 0.15021314555832108),
#  (('How To Bring Stale Chips And Bread Back From The Dead', 'W_n1uWBqjs8'),
#   0.15007464519881775),
#  (('Get out and #voteIRL - for SCIENCE.', 'ymk0yYehEcg'), 0.0470206504727263),
#  (('Why Voters Choose Authoritarian Leaders', '-_yKuvrfuwE'),
#   0.04649690288992009),
#  (('Creationism Creeping Into Schools', '1dtC052f9A4'), 0.04550335509294515),
#  (('Safe and Sorry –\xa0Terrorism & Mass Surveillance', 'V9_PjdU3Mpo'),
#   0.04519900838308203),
#  (('When Did Environmentalism Become So Political', 'r0tX54XUcHs'),
#   0.04381617346202283),
#  (('How Scientists Still Work Together, Even When Their Countries Don’t',
#    'Mbw7bWnH8SM'),
#   0.04340510746064473),
#  (("The Impact of the Gov't Shutdown on Science", 'NW-nBwl6mjc'),
#   0.04268642769467023),
#  (('Why Unlikeable Candidates Get Elected', 'oKsw3cgAugg'),
#   0.042592401040575135),
#  (('Why chemists marched for science – Speaking of Chemistry', '-LC5S4uKr1M'),
#   0.04146858176778844),
#  (('What Might Trump Mean for Chemistry — Speaking of Chemistry',
#    'XB0DNtXyd5w'),
#   0.04116997504319341),
#  (('Scientists and Science Supporters Marched--Now What', 'Rxtuog67nxU'),
#   0.03974811416985746),
#  (('Study Says Gun Owners Are Racist', '56HThf3mRpw'), 0.038950013207511125),
#  (('How Racially Diverse Emoji Will Make Us Better', 'dkMH2zatudE'),
#   0.0380093828134295),
#  (('Obama Loves Science', 'gG48sM-Y0UU'), 0.037648051114035797),
#  (('Are We The Only Species That Votes', '-XOis9RTROs'), 0.03734811648158843),
#  (("Why Can't We Vote Online", 'fin3OHjZa98'), 0.03697384094387603),
#  (('Do Women Make Better Leaders Than Men', 'El5UmZhIJ5c'),
#   0.036564996180032915),
#  (('TV Shows Are Changing Your Political Opinions Without You Knowing It',
#    'n4DDCMEy8lM'),
#   0.03613111970805497),
#  (('Can We Fix The Death Penalty', 'j1T_IW0oUx8'), 0.0356105652043482),
#  (('Is Internet Net Neutrality Really Dead', 'EDUlJEcDUvU'),
#   0.03403738639493962),
#  (('Can Game Theory Help A Presidential Candidate Win', 'Bc7CYIt7A2s'),
#   0.033967822586495965),
#  (('Are Great Leaders Born Or Made', 'z1R06oeY330'), 0.033635301713616554),
#  (('SciShow Marches for Science', 'LR8wkq-zd3E'), 0.03321372474786543),
#  (('Are Your Political Beliefs Genetic', 'OQ47gGbc40c'), 0.033210071919011215),
#  (('The Science of Terrorism', 'cb7ArmbIYIY'), 0.03286471242880517),
#  (('The Mind Games Politicians Use To Win Votes', '_JjReGEe8Mc'),
#   0.03210844938065998),
#  (('Vote!', 'CemrH5y1zCs'), 0.03042936101380174),
#  (('Should We Contact Uncontacted Peoples', 'gMMgMQVmNWQ'),
#   0.030382604627148375),
#  (('Should Bill Nye Debate a Creationist', '6bOTCk5U1AI'),
#   0.029251930909502746),
#  (('Why We Deny Our Problems', 'WBOn6l-voME'), 0.029116309642584777),
#  (('Will The Internet Kill Religion', '04jjBv6QR8k'), 0.029078824001568304),
#  (("Screening Room - Egypt's Fight for 'The Square'", 'TALRWu6y2mI'),
#   0.02813326507235215),
#  (('Help me INTERVIEW THE PRESIDENT - Smarter Every Day 150', '1OQ5a_BtEso'),
#   0.028030982279631397),
#  (('Why Do Some People Become Terrorists', 'oYuZLHkUD04'),
#   0.027997199870838336),
#  (('$500 MILLION DOLLARS - Smarter Every Day 179', 'G6N5DZLDja8'),
#   0.027803072093247172),
#  (('The Benefit Of Government-Owned Lands', 'xwSnikEYqWk'),
#   0.027690666459188946),
#  (('Can Peace be Purchased', '3-AGSdwVQRQ'), 0.02759216498520102),
#  (('Iraq Explained -- ISIS, Syria and War', 'AQPlREDW-Ro'),
#   0.026875403876678784),
#  (('What Is The Science Behind Polls', 'LbzYKfUpG7o'), 0.02678158980007477),
#  (('What I learned from President Obama - Smarter Every Day 151',
#    'GpWQHFzrEqc'),
#   0.026715920408414695),
#  (('World War Z - The Real Plan for Apocalypse', 'GyVdEODAKgQ'),
#   0.026107168098161233),
#  (('Do Presidents Age Faster Than The Rest Of Us', 'IH3d-qR25v4'),
#   0.026001159859521613),
#  (('How Are Conservative And Liberal Brains Different', 'V4nMzD1OmDE'),
#   0.02551733539311824),
#  (('Does Believing in God Make You Dumb', 'RZqaeusdMTk'),
#   0.024460947148034796),
#  (('Martin Luther King Jr. Day 2013 - How Far Have We Come', 'WWIudRXeY3s'),
#   0.024428389228489947),
#  (('President Obama is On DNews This Week!', 'g4wHrw-jTB8'),
#   0.024410472911387572),
#  (('Why Do Politics Make Us So Angry', 'KXR4-sQVu3g'), 0.0243989412957363),
#  (('The Legal Battle over CRISPR — Speaking of Chemistry', 'IboHEQumDGc'),
#   0.024284947847886734),
#  (('Wait… Is China Really the Leader in Green Energy', 'AKpj50et82c'),
#   0.02425648763010858),
#  (('Where the Catholic Church Stands on Science', '5IxV1PeM-mI'),
#   0.0241889248142958),
#  (("Why Facts Won't Help You Win Arguments", 'U0QLjA1GSVI'),
#   0.024145208254787744),
#  (('Can Your Face Get You Elected', 'M_CyqvcNooY'), 0.02360927065962612),
#  (("China's New Surveillance Tech Monitors Workers’ Brainwaves",
#    'cR-K0Lx-iRw'),
#   0.02304737732048673),
#  (('Should Teachers Carry Guns', 'kQKcROp6-6Q'), 0.022815458919146908),
#  (('Does God Make Society Better', 'OxKrHj4DK_w'), 0.022268502934199547),
#  (('Should Chimps Have Human Rights', '4U5pJsmV6RQ'), 0.02199179616519461),
#  (('The Science Of Racism', 'o8GoIfvnurY'), 0.02169435853686708),
#  (('Can Anyone Own Outer Space', 'gdHluCh3yVw'), 0.021468626614302655),
#  (('President Obama Explains Scott Kelly’s Year In Space', 'gfokS1J5VJw'),
#   0.021286035977463723),
#  (('The Monitor - Prime the Vote, Doritos for Science, and more..',
#    '6kCOXa39Ujo'),
#   0.020943688985080415),
#  (('U.S._Mexico Border Wall Puts Animals In Danger Of Extinction',
#    'l6xTxh96Jbc'),
#   0.020446098191107317),
#  (("How Our Brains Respond to People Who Aren't Like Us", 'KIwe_O0am4U'),
#   0.020163636189105844),
#  (('A Nobel Laureate Explains America’s Rigged Economy', 'y3hIyiwVBaI'),
#   0.020130028139168234),
#  (('NASA Needs You', 'xQhnwvoyEU4'), 0.02010864200721725),
#  (('Screening Room - A Good Day to Die for Civil Rights', 'MGVpI7OiUJ0'),
#   0.019453966079542726),
#  (('Is This The First Pro-Science Pope', 'udhWnbMVFks'), 0.01930929203266023),
#  (('Can Science Be a Religion', 'No7_fPhMWxc'), 0.018954656708197917),
#  (('Why Don’t Politicians Have Beards Anymore (ft. WheezyWaiter)',
#    'FPhSmSqvEnc'),
#   0.01895335523515438),
#  (('Why The War on Drugs Is a Huge Failure', 'wJUXLqNHCaI'),
#   0.018663764428146226),
#  (('Why We Love Seeing Other People Fail', 'i5pe4l3OFQw'),
#   0.018598026696923228),
#  (('How Science Is Keeping Antarctica Ungoverned', 'sKpA4ioawyY'),
#   0.01824270381454403),
#  (('Who Owns The Moon', 'Ks8WH3xUo_E'), 0.018202687145554498),
#  (('Endangered Species - an explainer', '_SxcMwpVkLo'), 0.017511886025132303),
#  (('When Is Assisted Suicide Okay Twins Choose Death Over Blindness',
#    'DgcAAoG9DLA'),
#   0.017460507650729665),
#  (("Campaigning for CHANGE! Don't be Shallow - Vote for Mallow",
#    'AxAPapIKTXc'),
#   0.017433358957421676),
#  (('The Importance of Preserving Outer Space Landmarks', 'z5TJKbtnJ7A'),
#   0.01732110762445981),
#  (('Pyrotherapy - An Awful Nobel Prize for Infecting People with Malaria',
#    '1fLzz5-gDok'),
#   0.017306035407308212),
#  (('The Abortion Rate Is At An All-Time Low, Why', '3jWjaHWQ-00'),
#   0.01711644643440668),
#  (('MinuteEarth Patreon Announcement + Tshirts', '2GA7p-V_Srk'),
#   0.01709648076652721),
#  (('How Bitcoin Became a Legit Virtual Currency', 'lcsZe34m2Us'),
#   0.017095361553801022),
#  (("America's Energy Future - MinuteEarth At The DemDebate", 'vbE5PSu-p0s'),
#   0.016838174990634457),
#  (('Are We Ready For Aliens', 'gCBlAAtJA54'), 0.016778046018613872),
#  (('Do You Need To Be Rich To Be Healthy (ft. Bill Gates)', 'PCTVL5oKlik'),
#   0.016603990612961344),
#  (('DemDebate Secret Video - What The U.S. Promised In Paris', 'pZD-FKaSyj4'),
#   0.016427614730560293),
#  (('Open Letter to the President - Physics Education', 'BGL22PTIOAM'),
#   0.016220906588625832),
#  (('Michael REVEALED !!!!', 'zo1Hd3tozKs'), 0.016003812381873952),
#  (('Climate Deal in Paris - Everything You Need to Know', 'qdqPoX9IV9A'),
#   0.015909933452696295),
#  (('Spotting Counterfeit Caviar, Macron Invites Trumped Scientists, and More - 60 Second Science Podcasts',
#    'ClKJ76JhWx8'),
#   0.015864880058556855),
#  (("Why Don't Some People Believe In Science", 'b1HrAKGTh0I'),
#   0.015827446118082317),
#  (('Is All Fair In Love And War', 'oThh3_Srxtc'), 0.01573394628572729),
#  (('How To Win An Argument', 'jdevcXHtkjg'), 0.015640741109188894),
#  (('Why Do People Think Bullsh_t is Profound', 'Ovc1BHMsCaw'),
#   0.015632686600859497),
#  (('That Time the US Government Poisoned Alcohol', 'bKKjWyOtyTg'),
#   0.015556840640856197),
#  (('Who Owns Outer Space - Instant Egghead #56', 'LQ7UgF0R_6E'),
#   0.015506986420695923),
#  (('Men wrestle 8 point deer to save its life (buck)', '2vKhZfM8nbg'),
#   0.015473026607729382),
#  (('The Plan To Stop Killer Robots', 'riwe0nc5lig'), 0.015135421211886185),
#  (('Does Power Make You Corrupt', 'Mj_x6Uq0YlQ'), 0.01490403767032471),
#  (('Names', 'p7THJoRYA2c'), 0.014811134486817583),
#  (('Banking Explained – Money and Credit', 'fTTGALaRZoc'),
#   0.01470872831747418),
#  (('Is the European Union Worth It Or Should We End It', 'XxutY7ss1v4'),
#   0.014571082841366441),
#  (("The UN's Plan To Defend Earth From Asteroids", 'te7vk2Z0VnU'),
#   0.014473628171522084),
#  (('This Is Your Brain On Extreme Weather', 'cJCczZd7HVk'),
#   0.014302370171684618),
#  (('How Does Having Too Much Power Affect Your Brain', 'GHZ7-kq3GDQ'),
#   0.014033185045643352),
#  (('How Two Students Were Inspired By a Forgotten Genius', 'Q9_sPDT0Q3Y'),
#   0.014024585348993566),
#  (('Scientific American presents Neil deGrasse Tyson', 'ViM2tmyGtrQ'),
#   0.013911923651952247),
#  (('Science Supports Gay Parents', 'IaA3R15fJis'), 0.013878038552326966),
#  (('Know the Law - Smarter Every Day 8', 'p7SWgstujAg'), 0.013874433410267742),
#  (("I'm Marching for Science!", 'LB6krdtWa7s'), 0.013849620656241719),
#  (('How Science Is Keeping Latin Alive', 'qT4XWxlnYdU'), 0.01354191486121379),
#  (("Can Cops Really Prove You're High", 'AeLLRfonwPE'), 0.013486913022056339),
#  (('Screening Room - How To Survive A Plague', '4eSKqQCjwUQ'),
#   0.01330603226454372),
#  (("Ricin Letters - What's So Dangerous", 'm5IMuNKeSn8'),
#   0.013305611112089475),
#  (('Is War Over — A Paradox Explained', 'NbuUW9i-mHs'), 0.01317441859752688),
#  (('Chemistry and the Flint Water Crisis - Speaking of Chemistry',
#    'k18vbGwPxz4'),
#   0.013171708110841993),
#  (('Are These Butterflies The Same', 'O4STc1r-nVs'), 0.013116324502013655),
#  (('Why We Enjoy Seeing People Fail', 'JlLRe1KJHnc'), 0.013067190195005216),
#  (('Time To Switch To The Metric System!', 'gdmz3O2lnMQ'),
#   0.012949988098006583),
#  (('The Monitor - Social Networks,  and AAAS Roundup', 'E9t2qFNh1hI'),
#   0.012903111315899676),
#  (('The European Refugee Crisis and Syria Explained', 'RvOnXh3NN9w'),
#   0.012707909108470868),
#  (('A Commitment to Curiosity.', 'wbf8nqMh0R0'), 0.012550476081041163),
#  (("Post-Truth - Why Facts Don't Matter Anymore", 'dvk2PQNcg8w'),
#   0.012370567104841959),
#  (('The Audubon Field Guide', 'AroBpWLqvng'), 0.012312491198559589),
#  (('The Drunk Astronomer Who Changed Science Forever', 'dE0ce4iScEo'),
#   0.012310516682688975),
#  (('Why We Should All Question Science', '_bRpLOAX9rc'), 0.01230525498338779),
#  (('Bringing Climate Change To The Classroom', 'QflQfcHvD4M'),
#   0.012106190431642856),
#  (('Why is the Statue of Liberty Green', '_ZSLrXtg1-o'), 0.0119990611502345),
#  (('Why We Blame Everything on Aliens', 'l0gNc1EtE-A'), 0.011850180108063787),
#  (('Should Doctors Use Twitter To Monitor Patients', 'ZwuktwlPZzM'),
#   0.011780806299561988),
#  (('Why Are People Going To Switzerland To Kill Themselves', '3lkkhq4kxxs'),
#   0.011731805006835813),
#  (('Why The Government Stops Gun Violence Research', 'xHp3SuLUnMM'),
#   0.01168705497160962),
#  (('How Japan Gets Away With Killing Whales', 'Sbnof_394I8'),
#   0.01166770495303019),
#  (('Patenting Person Parts', 'kUpgfARGmXs'), 0.011553513694692513),
#  (('How Common Are Gay Animals', '3eSIxmau_Is'), 0.011533648222778302),
#  (('Do Robots Deserve Rights What if Machines Become Conscious',
#    'DHyUYg8X31c'),
#   0.011296913098472895),
#  (("The Best Way to Convince Someone They're Wrong", 'sJ64h49gSwY'),
#   0.011215401004212418),
#  (('Is Obama Stressed Out Why We Go Gray', 'Cd2Y1qDaGcc'),
#   0.011125480598998757),
#  (('Using Your Selfies For Science!', '0vfzregNj_g'), 0.01096118846770126),
#  (('JFK Assassination - Why We Still Believe the Conspiracies', 'oZ-3Ln6VPIo'),
#   0.010956159406607734),
#  (('How Nostalgic Memories Manipulate Your Reality', 'ijVMWZAC6A8'),
#   0.010883796544061387),
#  (('Emergence – How Stupid Things Become Smart Together', '16W7c0mb-rE'),
#   0.010801973787924838),
#  (('How Can Scientists Help Make Cities More Sustainable', 'f8mff4wGid8'),
#   0.010772075080812094),
#  (('Interview with EPA Administrator McCarthy', 'fW-jOrtXmJU'),
#   0.010681424321775853),
#  (('Climate Change - The View From MinuteEarth _ #OursToLose', 'MEX2J_sAdGs'),
#   0.010537840802036926),
#  (('The Ozone Layer Was Doomed Until a Handful of Scientists Stood Up to Power',
#    'CvcvMkFGBi8'),
#   0.01045670417710531),
#  (('Football Disease, Moon Base Dreams, and the Deepest Vents Ever!',
#    'ax-032AtQKg'),
#   0.010437246849640897),
#  (('How Do Abortions Work', 'swoWhrERRNk'), 0.010417862735298699),
#  (('Should We Legalize Psychedelics For Science', 'C8clPUI7f8I'),
#   0.010375626135988072),
#  (('The Ultimate Conspiracy Debunker', 'Hug0rfFC_L8'), 0.010284693481072913),
#  (('Why Have We Stopped Caring About Mass Shootings', '2K2IP_Vz4kM'),
#   0.01026603492895529),
#  (('Getting A DNA Test Could Keep You From Your Dream Job', '6EPpjOAeOtg'),
#   0.010107674184377441),
#  (('Can Your Boss Spy On Your Internet Use', 'st2qjZXspTk'),
#   0.010073856321451224),
#  (("An Astronaut's View of Earth", '6YOz9Pxnzho'), 0.010052132055964863),
#  (('Climate Change is Boring', 'eNx9tvCrvv8'), 0.010002166647339612)]

# %% [markdown]
# # update interest vector

# %%
vv.update_interest_vector(interest_vec, prev_video=('What Your Drink Says About Your Politics', 'rdoUojbCfjk'))
# Out:
# array([9.86522330e-01, 1.37180339e-04, 2.96458314e-04, 3.27611181e-05,
#        1.28036671e-03, 1.11712140e-03, 7.34916968e-05, 6.82541462e-06,
#        1.21089875e-03, 3.62656553e-02, 1.62016043e-05, 1.47018327e-04,
#        3.93463939e-04, 5.36163756e-03, 1.79165231e-03, 8.27099208e-03,
#        1.03945717e-03, 2.25911788e-03, 2.09346629e-02, 5.71284230e-04,
#        0.00000000e+00, 3.58201516e-04, 7.93990969e-03, 4.23049602e-03,
#        7.47967202e-04, 9.20865848e-04, 1.73541606e-03, 7.11531135e-02,
#        9.45783171e-05, 1.70179438e-05, 2.23952506e-03, 2.83625824e-03,
#        2.01359949e-03, 8.92987120e-04, 7.67562046e-04, 8.76020840e-02,
#        1.20735937e-02, 5.26675576e-05, 0.00000000e+00, 7.61999294e-03,
#        2.12843647e-03, 5.78043329e-04, 2.35864996e-03, 2.32065223e-02,
#        2.30981782e-03, 6.72781318e-03, 1.59164327e-03, 1.62465830e-03,
#        9.76286465e-04, 1.61203363e-03, 1.23127857e-02, 6.11358770e-05,
#        0.00000000e+00, 4.65810833e-03, 5.86727402e-05, 1.66928883e-02,
#        1.19252130e-02, 0.00000000e+00, 2.42170822e-03, 5.73957405e-03,
#        4.03483633e-02, 0.00000000e+00, 9.61106904e-03, 3.33772713e-04,
#        1.17526109e-04, 1.45047486e-02, 3.66065102e-03, 2.49190403e-04,
#        9.90223116e-06, 1.30025376e-03, 1.54099841e-03, 0.00000000e+00,
#        5.59757363e-03, 6.20587888e-03, 3.92834081e-04, 4.89688996e-03,
#        2.33515500e-02, 1.25851041e-03, 7.07471218e-04, 2.49147261e-06,
#        1.15772348e-03, 1.31398738e-02, 8.48813145e-03, 1.58074755e-03,
#        5.24697444e-03, 4.61008425e-03, 0.00000000e+00, 1.41992647e-03,
#        5.05390678e-03, 0.00000000e+00, 4.27648849e-05, 1.65082744e-03,
#        2.99564704e-05, 0.00000000e+00, 0.00000000e+00, 3.18541826e-05,
#        7.77148989e-03, 4.28604366e-03, 2.83443498e-03, 6.06813670e-04,
#        4.20813764e-03, 8.76660047e-04, 1.58758098e-02, 1.42818525e-02,
#        7.67607598e-03, 1.94756900e-02, 0.00000000e+00, 2.27841950e-02,
#        2.57868533e-03, 1.49767261e-06, 3.07581089e-03, 7.67977289e-03,
#        9.04269395e-04, 1.28539440e-03, 3.33930192e-03, 1.90233596e-03,
#        7.87621307e-04, 1.88741172e-05, 0.00000000e+00, 5.64163181e-03,
#        7.32305573e-04, 0.00000000e+00, 6.04851946e-04, 0.00000000e+00,
#        1.63274362e-05, 4.54407297e-03, 1.76689931e-05, 7.77493212e-04,
#        6.25088160e-03, 6.25829203e-02, 2.29124359e-02, 6.62370300e-04,
#        3.46297150e-03, 2.81420006e-03, 2.97473558e-04, 8.23395110e-05,
#        1.01760800e-02, 1.27064357e-05, 0.00000000e+00, 4.31502307e-03,
#        2.32488557e-02, 3.46500976e-04, 2.41562953e-03, 3.57407890e-05,
#        0.00000000e+00, 1.00323891e-02, 4.71846181e-03, 2.37820494e-02,
#        2.25368442e-02, 0.00000000e+00, 1.78623396e-03, 1.11513005e-03,
#        1.28713874e-04, 4.26475242e-05, 2.58695364e-03, 4.68328635e-05,
#        1.09714516e-02, 0.00000000e+00, 6.21725808e-03, 1.24000998e-03,
#        3.44262587e-04, 4.35483735e-04, 2.15265435e-04, 1.26224331e-02,
#        3.31674695e-04, 1.70520743e-03, 1.75565179e-02, 9.37162471e-03,
#        7.50079760e-03, 2.77575507e-03, 0.00000000e+00, 0.00000000e+00,
#        2.45262678e-05, 0.00000000e+00, 9.67139711e-03, 0.00000000e+00,
#        2.46773792e-02, 9.91424752e-04, 6.71481677e-04, 8.53835813e-03])
